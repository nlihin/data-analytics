# %% [markdown]
# # Worldwide DATA
#
# ![](https://img.freepik.com/free-vector/global-network-connection-world-wide-web-connection-lines_110633-43.jpg?size=426&ext=jpg)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/ANproject1/Part_A/main/world_data.csv'
world_wide = pd.read_csv(url).copy()
world_wide.head()
# Out:
#   Country Name Country Code  year  Access to electricity (% of population)  \
# 0  Afghanistan          AFG  1960                                      NaN
# 1  Afghanistan          AFG  1961                                      NaN
# 2  Afghanistan          AFG  1962                                      NaN
# 3  Afghanistan          AFG  1963                                      NaN
# 4  Afghanistan          AFG  1964                                      NaN
#
#    Access to electricity, rural (% of rural population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Agricultural land (% of land area)  Agricultural land (sq. km)  \
# 0                                 NaN                         NaN
# 1                           57.745918                    377000.0
# 2                           57.837821                    377600.0
# 3                           57.914407                    378100.0
# 4                           58.010906                    378730.0
#
#    Agricultural machinery, tractors  \
# 0                               NaN
# 1                             120.0
# 2                             150.0
# 3                             200.0
# 4                             200.0
#
#    Agricultural machinery, tractors per 100 sq. km of arable land  ...  \
# 0                                                NaN               ...
# 1                                           0.156863               ...
# 2                                           0.194805               ...
# 3                                           0.258065               ...
# 4                                           0.256410               ...
#
#    Permanent cropland (% of land area)  Population, total  \
# 0                                  NaN          8996973.0
# 1                             0.076586          9169410.0
# 2                             0.091903          9351441.0
# 3                             0.091903          9543205.0
# 4                             0.111816          9744781.0
#
#    Rural land area (sq. km)  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
#    Rural land area where elevation is below 5 meters (% of total land area)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Rural land area where elevation is below 5 meters (sq. km)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Rural population  Rural population (% of total population)  \
# 0         8241137.0                                    91.599
# 1         8373138.0                                    91.316
# 2         8512056.0                                    91.024
# 3         8657977.0                                    90.724
# 4         8810646.0                                    90.414
#
#    Rural population growth (annual %)  \
# 0                                 NaN
# 1                            1.589040
# 2                            1.645479
# 3                            1.699758
# 4                            1.747967
#
#    Rural population living in areas where elevation is below 5 meters (% of total population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Surface area (sq. km)
# 0                    NaN
# 1               652860.0
# 2               652860.0
# 3               652860.0
# 4               652860.0
#
# [5 rows x 55 columns]

# %% [markdown]
# Checking the data settings

# %%
world_wide=world_wide.rename(columns={'Country Name':'Country'})
world_wide.dtypes
# Out:
# Country                                                                                        object
# Country Code                                                                                   object
# year                                                                                            int64
# Access to electricity (% of population)                                                       float64
# Access to electricity, rural (% of rural population)                                          float64
# Agricultural irrigated land (% of total agricultural land)                                    float64
# Agricultural land (% of land area)                                                            float64
# Agricultural land (sq. km)                                                                    float64
# Agricultural machinery, tractors                                                              float64
# Agricultural machinery, tractors per 100 sq. km of arable land                                float64
# Agricultural methane emissions (% of total)                                                   float64
# Agricultural methane emissions (thousand metric tons of CO2 equivalent)                       float64
# Agricultural nitrous oxide emissions (% of total)                                             float64
# Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)                 float64
# Agricultural raw materials exports (% of merchandise exports)                                 float64
# Agricultural raw materials imports (% of merchandise imports)                                 float64
# Agriculture, forestry, and fishing, value added (% of GDP)                                    float64
# Agriculture, forestry, and fishing, value added (current US$)                                 float64
# Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)                 float64
# Arable land (% of land area)                                                                  float64
# Arable land (hectares per person)                                                             float64
# Arable land (hectares)                                                                        float64
# Average precipitation in depth (mm per year)                                                  float64
# Birth rate, crude (per 1,000 people)                                                          float64
# Cereal production (metric tons)                                                               float64
# Cereal yield (kg per hectare)                                                                 float64
# CPIA gender equality rating (1=low to 6=high)                                                 float64
# Crop production index (2004-2006 = 100)                                                       float64
# Death rate, crude (per 1,000 people)                                                          float64
# Employment in agriculture (% of total employment) (modeled ILO estimate)                      float64
# Employment in agriculture, female (% of female employment) (modeled ILO estimate)             float64
# Employment in agriculture, male (% of male employment) (modeled ILO estimate)                 float64
# Fertilizer consumption (% of fertilizer production)                                           float64
# Fertilizer consumption (kilograms per hectare of arable land)                                 float64
# Food production index (2004-2006 = 100)                                                       float64
# Forest area (% of land area)                                                                  float64
# Forest area (sq. km)                                                                          float64
# GDP per capita (current US$)                                                                  float64
# Land area (sq. km)                                                                            float64
# Land under cereal production (hectares)                                                       float64
# Literacy rate, adult total (% of people ages 15 and above)                                    float64
# Livestock production index (2004-2006 = 100)                                                  float64
# Mineral rents (% of GDP)                                                                      float64
# Mortality rate, infant (per 1,000 live births)                                                float64
# Net migration                                                                                 float64
# Permanent cropland (% of land area)                                                           float64
# Population, total                                                                             float64
# Rural land area (sq. km)                                                                      float64
# Rural land area where elevation is below 5 meters (% of total land area)                      float64
# Rural land area where elevation is below 5 meters (sq. km)                                    float64
# Rural population                                                                              float64
# Rural population (% of total population)                                                      float64
# Rural population growth (annual %)                                                            float64
# Rural population living in areas where elevation is below 5 meters (% of total population)    float64
# Surface area (sq. km)                                                                         float64
# dtype: object

# %% [markdown]
# the dataset contains information from years 1960-2020, were only intrested from year 2000 and forward.

# %%
world_wide = world_wide[world_wide['year'] >= 2000]
world_wide.shape
# Out:
# (5544, 55)

# %% [markdown]
# ---
# # 1. Arranging the data

# %% [markdown]
# ## 1.1 missing values

# %% [markdown]
# There's a large amount of columns, we would like to filter some of them.

# %%
world_wide.isnull().sum().sort_values(ascending=False)
# Out:
# Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)                 5136
# Rural land area where elevation is below 5 meters (% of total land area)                      5098
# Rural land area where elevation is below 5 meters (sq. km)                                    5094
# Rural land area (sq. km)                                                                      5094
# Rural population living in areas where elevation is below 5 meters (% of total population)    5094
# Agricultural machinery, tractors per 100 sq. km of arable land                                4916
# Agricultural machinery, tractors                                                              4884
# Average precipitation in depth (mm per year)                                                  4791
# Agricultural irrigated land (% of total agricultural land)                                    4688
# Net migration                                                                                 4584
# Literacy rate, adult total (% of people ages 15 and above)                                    4046
# CPIA gender equality rating (1=low to 6=high)                                                 3806
# Fertilizer consumption (% of fertilizer production)                                           3719
# Agricultural methane emissions (% of total)                                                   3300
# Agricultural nitrous oxide emissions (% of total)                                             3291
# Agricultural methane emissions (thousand metric tons of CO2 equivalent)                       3177
# Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)                 3177
# Fertilizer consumption (kilograms per hectare of arable land)                                 2557
# Arable land (hectares)                                                                        2048
# Agricultural raw materials exports (% of merchandise exports)                                 1564
# Agricultural raw materials imports (% of merchandise imports)                                 1536
# Cereal yield (kg per hectare)                                                                 1515
# Land under cereal production (hectares)                                                       1514
# Cereal production (metric tons)                                                               1496
# Crop production index (2004-2006 = 100)                                                       1471
# Livestock production index (2004-2006 = 100)                                                  1454
# Permanent cropland (% of land area)                                                           1442
# Food production index (2004-2006 = 100)                                                       1437
# Arable land (hectares per person)                                                             1277
# Arable land (% of land area)                                                                  1272
# Agricultural land (% of land area)                                                            1237
# Agricultural land (sq. km)                                                                    1225
# Forest area (% of land area)                                                                  1210
# Forest area (sq. km)                                                                          1198
# Agriculture, forestry, and fishing, value added (current US$)                                  945
# Agriculture, forestry, and fishing, value added (% of GDP)                                     917
# Access to electricity, rural (% of rural population)                                           909
# Mineral rents (% of GDP)                                                                       795
# Death rate, crude (per 1,000 people)                                                           782
# Access to electricity (% of population)                                                        782
# Birth rate, crude (per 1,000 people)                                                           776
# Mortality rate, infant (per 1,000 live births)                                                 764
# Employment in agriculture, male (% of male employment) (modeled ILO estimate)                  651
# Employment in agriculture, female (% of female employment) (modeled ILO estimate)              651
# Employment in agriculture (% of total employment) (modeled ILO estimate)                       651
# Surface area (sq. km)                                                                          590
# Land area (sq. km)                                                                             590
# GDP per capita (current US$)                                                                   574
# Rural population growth (annual %)                                                             530
# Rural population                                                                               332
# Rural population (% of total population)                                                       332
# Population, total                                                                              292
# year                                                                                             0
# Country Code                                                                                     0
# Country                                                                                          0
# dtype: int64

# %% [markdown]
# There's no use to work with columns that got more then 3000 of NAN values (more than 50%)..

# %%
new_df=pd.DataFrame(world_wide.isnull().sum().sort_values(ascending=False))
drop_features=new_df[new_df[0]>3000].index
world_wide=world_wide.drop(columns=drop_features)
world_wide.isnull().sum().sort_values(ascending=False)
# Out:
# Fertilizer consumption (kilograms per hectare of arable land)                        2557
# Arable land (hectares)                                                               2048
# Agricultural raw materials exports (% of merchandise exports)                        1564
# Agricultural raw materials imports (% of merchandise imports)                        1536
# Cereal yield (kg per hectare)                                                        1515
# Land under cereal production (hectares)                                              1514
# Cereal production (metric tons)                                                      1496
# Crop production index (2004-2006 = 100)                                              1471
# Livestock production index (2004-2006 = 100)                                         1454
# Permanent cropland (% of land area)                                                  1442
# Food production index (2004-2006 = 100)                                              1437
# Arable land (hectares per person)                                                    1277
# Arable land (% of land area)                                                         1272
# Agricultural land (% of land area)                                                   1237
# Agricultural land (sq. km)                                                           1225
# Forest area (% of land area)                                                         1210
# Forest area (sq. km)                                                                 1198
# Agriculture, forestry, and fishing, value added (current US$)                         945
# Agriculture, forestry, and fishing, value added (% of GDP)                            917
# Access to electricity, rural (% of rural population)                                  909
# Mineral rents (% of GDP)                                                              795
# Access to electricity (% of population)                                               782
# Death rate, crude (per 1,000 people)                                                  782
# Birth rate, crude (per 1,000 people)                                                  776
# Mortality rate, infant (per 1,000 live births)                                        764
# Employment in agriculture (% of total employment) (modeled ILO estimate)              651
# Employment in agriculture, female (% of female employment) (modeled ILO estimate)     651
# Employment in agriculture, male (% of male employment) (modeled ILO estimate)         651
# Surface area (sq. km)                                                                 590
# Land area (sq. km)                                                                    590
# GDP per capita (current US$)                                                          574
# Rural population growth (annual %)                                                    530
# Rural population                                                                      332
# Rural population (% of total population)                                              332
# Population, total                                                                     292
# year                                                                                    0
# Country Code                                                                            0
# Country                                                                                 0
# dtype: int64

# %% [markdown]
# ## 1.2 Transformations and understanding

# %% [markdown]
# **undrestanding the data:**
# The info that contained in the dataset needed to be exists every year. the chance of being 0 or non-existent (nan) is not possible.
# so we can conclude that NAN values have to be a report mistake or forgeten to be updated.

# %% [markdown]
# were ussing fillna function with **groupby** inside by country to prevent leakage of incorrect information from one country to another.

# %%
world_wide.fillna(world_wide.groupby('Country').transform('median'), inplace=True)

# %% [markdown]
# After arranging the data.\
# there are over 250 countries in the dataset, which contains information about agriculture, population, employment, death and more for each country ...
#
# **and our question is:**
# ## how did each country go along the years?

# %% [markdown]
# using **groupby** command to caculate the mean according to the requested years.

# %%
world_wide= world_wide.groupby('Country').mean()
world_wide.head()
# Out:
#                 year  Access to electricity (% of population)  \
# Country
# Afghanistan     2010                                59.717459
# Albania         2010                                99.995238
# Algeria         2010                                99.586994
# American Samoa  2010                                      NaN
# Andorra         2010                               100.000000
#
#                 Access to electricity, rural (% of rural population)  \
# Country
# Afghanistan                                             50.364246
# Albania                                                100.000000
# Algeria                                                 98.645244
# American Samoa                                                NaN
# Andorra                                                100.000000
#
#                 Agricultural land (% of land area)  \
# Country
# Afghanistan                              58.033371
# Albania                                  42.375131
# Algeria                                  17.243179
# American Samoa                           24.342858
# Andorra                                  44.249240
#
#                 Agricultural land (sq. km)  \
# Country
# Afghanistan                  378876.666667
# Albania                       11610.785900
# Algeria                      410687.680432
# American Samoa                   48.685715
# Andorra                         207.971430
#
#                 Agricultural raw materials exports (% of merchandise exports)  \
# Country
# Afghanistan                                              8.839448
# Albania                                                  4.326071
# Algeria                                                  0.021376
# American Samoa                                                NaN
# Andorra                                                  1.201181
#
#                 Agricultural raw materials imports (% of merchandise imports)  \
# Country
# Afghanistan                                              0.948878
# Albania                                                  0.934849
# Algeria                                                  1.752884
# American Samoa                                                NaN
# Andorra                                                  0.405082
#
#                 Agriculture, forestry, and fishing, value added (% of GDP)  \
# Country
# Afghanistan                                             26.028548
# Albania                                                 19.441444
# Algeria                                                  9.520649
# American Samoa                                                NaN
# Andorra                                                       NaN
#
#                 Agriculture, forestry, and fishing, value added (current US$)  \
# Country
# Afghanistan                                          3.457134e+09
# Albania                                              1.969125e+09
# Algeria                                              1.357122e+10
# American Samoa                                                NaN
# Andorra                                                       NaN
#
#                 Arable land (% of land area)  ...  \
# Country                                       ...
# Afghanistan                        11.903376  ...
# Albania                            21.863399  ...
# Algeria                             3.149916  ...
# American Samoa                     14.928571  ...
# Andorra                             1.700101  ...
#
#                 Land under cereal production (hectares)  \
# Country
# Afghanistan                                2.829380e+06
# Albania                                    1.481326e+05
# Algeria                                    2.626491e+06
# American Samoa                                      NaN
# Andorra                                             NaN
#
#                 Livestock production index (2004-2006 = 100)  \
# Country
# Afghanistan                                       100.886190
# Albania                                           101.784762
# Algeria                                           112.023810
# American Samoa                                    100.479524
# Andorra                                                  NaN
#
#                 Mineral rents (% of GDP)  \
# Country
# Afghanistan                     0.001718
# Albania                         0.231521
# Algeria                         0.098627
# American Samoa                  0.000000
# Andorra                         0.000000
#
#                 Mortality rate, infant (per 1,000 live births)  \
# Country
# Afghanistan                                          66.414286
# Albania                                              13.821429
# Algeria                                              25.457143
# American Samoa                                             NaN
# Andorra                                               4.480952
#
#                 Permanent cropland (% of land area)  Population, total  \
# Country
# Afghanistan                                0.177461       2.928106e+07
# Albania                                    3.534411       2.947122e+06
# Algeria                                    0.362310       3.619142e+07
# American Samoa                             9.414286       5.710138e+04
# Andorra                                         NaN       7.802767e+04
#
#                 Rural population  Rural population (% of total population)  \
# Country
# Afghanistan         2.228462e+07                                 76.300405
# Albania             1.432264e+06                                 48.458500
# Algeria             1.181943e+07                                 33.046714
# American Samoa      7.008310e+03                                 12.277786
# Andorra             8.311976e+03                                 10.563119
#
#                 Rural population growth (annual %)  Surface area (sq. km)
# Country
# Afghanistan                               2.919897               652860.0
# Albania                                  -2.513548                28750.0
# Algeria                                  -0.406291              2381740.0
# American Samoa                            0.239707                  200.0
# Andorra                                   3.269140                  470.0
#
# [5 rows x 36 columns]

# %% [markdown]
# Countries that still have NAN values should be droped,  they have not been updated at all over the years.

# %% [markdown]
# ## 1.3 Outliers

# %%
world_wide= world_wide.dropna(axis=0)
world_wide= world_wide.drop(columns= 'year')
world_wide.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148 entries, Afghanistan to Zimbabwe
# Data columns (total 35 columns):
#  #   Column                                                                             Non-Null Count  Dtype
# ---  ------                                                                             --------------  -----
#  0   Access to electricity (% of population)                                            148 non-null    float64
#  1   Access to electricity, rural (% of rural population)                               148 non-null    float64
#  2   Agricultural land (% of land area)                                                 148 non-null    float64
#  3   Agricultural land (sq. km)                                                         148 non-null    float64
#  4   Agricultural raw materials exports (% of merchandise exports)                      148 non-null    float64
#  5   Agricultural raw materials imports (% of merchandise imports)                      148 non-null    float64
#  6   Agriculture, forestry, and fishing, value added (% of GDP)                         148 non-null    float64
#  7   Agriculture, forestry, and fishing, value added (current US$)                      148 non-null    float64
#  8   Arable land (% of land area)                                                       148 non-null    float64
#  9   Arable land (hectares per person)                                                  148 non-null    float64
#  10  Arable land (hectares)                                                             148 non-null    float64
#  11  Birth rate, crude (per 1,000 people)                                               148 non-null    float64
#  12  Cereal production (metric tons)                                                    148 non-null    float64
#  13  Cereal yield (kg per hectare)                                                      148 non-null    float64
#  14  Crop production index (2004-2006 = 100)                                            148 non-null    float64
#  15  Death rate, crude (per 1,000 people)                                               148 non-null    float64
#  16  Employment in agriculture (% of total employment) (modeled ILO estimate)           148 non-null    float64
#  17  Employment in agriculture, female (% of female employment) (modeled ILO estimate)  148 non-null    float64
#  18  Employment in agriculture, male (% of male employment) (modeled ILO estimate)      148 non-null    float64
#  19  Fertilizer consumption (kilograms per hectare of arable land)                      148 non-null    float64
#  20  Food production index (2004-2006 = 100)                                            148 non-null    float64
#  21  Forest area (% of land area)                                                       148 non-null    float64
#  22  Forest area (sq. km)                                                               148 non-null    float64
#  23  GDP per capita (current US$)                                                       148 non-null    float64
#  24  Land area (sq. km)                                                                 148 non-null    float64
#  25  Land under cereal production (hectares)                                            148 non-null    float64
#  26  Livestock production index (2004-2006 = 100)                                       148 non-null    float64
#  27  Mineral rents (% of GDP)                                                           148 non-null    float64
#  28  Mortality rate, infant (per 1,000 live births)                                     148 non-null    float64
#  29  Permanent cropland (% of land area)                                                148 non-null    float64
#  30  Population, total                                                                  148 non-null    float64
#  31  Rural population                                                                   148 non-null    float64
#  32  Rural population (% of total population)                                           148 non-null    float64
#  33  Rural population growth (annual %)                                                 148 non-null    float64
#  34  Surface area (sq. km)                                                              148 non-null    float64
# dtypes: float64(35)
# memory usage: 41.6+ KB

# %% [markdown]
# ---
# # 2. Correlations

# %%
features= ['Access to electricity (% of population)','Agricultural land (% of land area)' \
           ,'Birth rate, crude (per 1,000 people)', 'Death rate, crude (per 1,000 people)', \
          'Employment in agriculture (% of total employment) (modeled ILO estimate)', 'Forest area (% of land area)', \
          'GDP per capita (current US$)', 'Land area (sq. km)','Mineral rents (% of GDP)', \
          'Population, total','Rural population (% of total population)','Surface area (sq. km)', \
          'Agricultural land (sq. km)']
features
# Out:
# ['Access to electricity (% of population)',
#  'Agricultural land (% of land area)',
#  'Birth rate, crude (per 1,000 people)',
#  'Death rate, crude (per 1,000 people)',
#  'Employment in agriculture (% of total employment) (modeled ILO estimate)',
#  'Forest area (% of land area)',
#  'GDP per capita (current US$)',
#  'Land area (sq. km)',
#  'Mineral rents (% of GDP)',
#  'Population, total',
#  'Rural population (% of total population)',
#  'Surface area (sq. km)',
#  'Agricultural land (sq. km)']

# %% [markdown]
# Checking if there is Correlations with the features that we chose.
# The numbers are by country, and do not come from a normal distribution. Therefore, we will use the kendall-tau method.

# %%
corrs = world_wide[features].corr(method = 'kendall')

plt.figure(figsize=(15,12))
sns.heatmap(corrs, cmap='Blues', center=0, annot = True);

# %% [markdown]
# **found some!**

# %% [markdown]
# wow! theres Correlations that shows us a perfect match (0.99) between\
# Surface area (sq. km) **&** Land area (sq. km).\
# **but** it is quite clear that there is a strong connection between them, still perfect match Requires visual check.

# %%
world_wide.loc[:,['Surface area (sq. km)','Land area (sq. km)']]
# Out:
#                Surface area (sq. km)  Land area (sq. km)
# Country
# Afghanistan             6.528600e+05        6.528600e+05
# Albania                 2.875000e+04        2.740000e+04
# Algeria                 2.381740e+06        2.381740e+06
# Angola                  1.246700e+06        1.246700e+06
# Argentina               2.780400e+06        2.736690e+06
# ...                              ...                 ...
# Venezuela, RB           9.120500e+05        8.820500e+05
# Vietnam                 3.306790e+05        3.101886e+05
# Yemen, Rep.             5.279700e+05        5.279700e+05
# Zambia                  7.526100e+05        7.433900e+05
# Zimbabwe                3.907600e+05        3.868500e+05
#
# [148 rows x 2 columns]

# %%
world_wide.loc[:,['Surface area (sq. km)','Land area (sq. km)']].plot(use_index=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There are countries that got excactly the same sq.km in both columns, that showed us land area isnt Precise.\
# we'll drop it from the features and start again.

# %%
features.remove('Land area (sq. km)')

# %%
corrs = world_wide[features].corr(method = 'kendall')

plt.figure(figsize=(15,12))
sns.heatmap(corrs, cmap='Blues', center=0, annot = True);

# %% [markdown]
# moving to the next strong Correlation conection between(0.77):\
# Surface area (sq. km) **&** Agricultural land (sq. km)

# %%
sns.regplot(x='Agricultural land (sq. km)', y='Surface area (sq. km)', data=world_wide);

# %% [markdown]
# ---
# ## conclusion 1
#
# There is similar behavior of countries all over the world.\
# **The larger the surface area, the larger the agricultural area.**
#
# ---

# %% [markdown]
# ## What about the economy and wealth of the country? And how does it affect?

# %% [markdown]
# moving to the next stong Correlation between:\
# GDP per capita (current US$) **&** Employment in agriculture (% of total employment) (modeled ILO estimate)

# %% [markdown]
# ### what is GDP?
# gross domestic product
#
# ![](data:image/jpeg;base64,...)

# %%
sns.regplot(x='GDP per capita (current US$)'\
            , y='Employment in agriculture (% of total employment) (modeled ILO estimate)', data=world_wide);

# %% [markdown]
# According to the current graph, it is difficult to see the relations behavior..\
# Let's reduce the GDP limit.

# %%
sns.regplot(x='GDP per capita (current US$)'\
            , y='Employment in agriculture (% of total employment) (modeled ILO estimate)', data=world_wide\
           [world_wide['GDP per capita (current US$)'] < 60000]);

# %% [markdown]
# Now we can conclude the relationship, we notice that the graph is divided into 2 different behaviors.
#
# **1. when GDP<20k:** The percentage of employment in agriculture decreases significantly when the value of GDP increases.
#
# **2. when GDP>20k:** When GDP rise above the 20k limit the percentage of agricultural employment in the country aims to 0!

# %%
fig, axes = plt.subplots(1,2, figsize=(15, 5))
first_plt = sns.regplot(x='GDP per capita (current US$)'\
            , y='Employment in agriculture (% of total employment) (modeled ILO estimate)', data=world_wide\
           [world_wide['GDP per capita (current US$)'] < 20000], color="y" ,ax=axes[0]);
second_plt = sns.regplot(x='GDP per capita (current US$)'\
            , y='Employment in agriculture (% of total employment) (modeled ILO estimate)', data=world_wide\
           [world_wide['GDP per capita (current US$)'] > 20000],ax=axes[1]);

# %% [markdown]
# In addition we can say that:
# GDP<20k==Poor contries.
# GDP>20K==Rich contries.

# %% [markdown]
# ---
# ## conclusion 2
#
# The percentage of agricultural employment in poor countries  is large.\
# while the employment of agriculture in the rich and developed countries has almost ceased to exist.
#
# ---

# %% [markdown]
# ### But is GDP is a measure that can determine the quality of a countries citizen's life?

# %% [markdown]
# This measure has a disadvantage, it measures the wealth of the country.\
# but a rich country does not necessarily indicate rich citizens.

# %% [markdown]
# There are countries rich in oil and thus the GDP measurement is quite high,\
# the citizens of the country live in poverty and high unemployment rates.

# %% [markdown]
# ### So how can we point out countries with high GDP that are impacting for the benefit of the citizens?

# %% [markdown]
# to answer that question, Let's look for more connections between GDP and indicators that indicate the quality of life of citizens.\
# **Access to electricity (% of population) & Rural population (% of total population)**

# %%
fig, axes = plt.subplots(1,2, figsize=(15, 5))
first_plt = sns.regplot(x='GDP per capita (current US$)'\
            , y='Access to electricity (% of population)', data=world_wide, color="r" ,ax=axes[0]);
second_plt = sns.regplot(x='GDP per capita (current US$)'\
            , y='Rural population (% of total population)', data=world_wide, color="g" ,ax=axes[1]);

# %% [markdown]
# **found some good news :)**\
# it seems that GDP measure can indicate us the citizen's quality life after all!

# %% [markdown]
# ---
# ## conclusion 3
#
# GDP has been shown to be effective in measuring the basic standard of living of the citizens in certain countries.
#
# ---

# %% [markdown]
# # Summary
#
# **According to the data, the countries of the world behave similarly in many cases. this gives us the potential to diagnose and draw important conclusions about the behavior of the modern world.**
