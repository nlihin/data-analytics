# %% [markdown]
# # Unit 3 - Conditional selection

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.csv'
vacc_df = pd.read_csv(url)

# %% [markdown]
# ### Selection with one condition

# %% [markdown]
# Our condition: only data from Israel

# %%
vacc_df.loc[:,'location'] == 'Israel'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 186366    False
# 186367    False
# 186368    False
# 186369    False
# 186370    False
# Name: location, Length: 186371, dtype: bool

# %% [markdown]
# This creates a series of true/false
#
# We can insert this into the dataframe to select only that task:

# %%
vacc_df[vacc_df.loc[:,'location'] == 'Israel']
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 81520   Israel      ISR  2020-12-19                75.0               71.0
# 81521   Israel      ISR  2020-12-20              7472.0             7468.0
# 81522   Israel      ISR  2020-12-21             32395.0            32391.0
# 81523   Israel      ISR  2020-12-22             77064.0            77060.0
# 81524   Israel      ISR  2020-12-23            139981.0           139977.0
# ...        ...      ...         ...                 ...                ...
# 82382   Israel      ISR  2023-04-30          18648958.0          6723106.0
# 82383   Israel      ISR  2023-05-01          18649010.0          6723107.0
# 82384   Israel      ISR  2023-05-02          18649126.0          6723117.0
# 82385   Israel      ISR  2023-05-03          18649185.0          6723118.0
# 82386   Israel      ISR  2023-05-04          18649248.0          6723119.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 81520                      4.0             NaN                     NaN
# 81521                      4.0             NaN                  7397.0
# 81522                      4.0             NaN                 24923.0
# 81523                      4.0             NaN                 44669.0
# 81524                      4.0             NaN                 62917.0
# ...                        ...             ...                     ...
# 82382                6159805.0       5766047.0                     NaN
# 82383                6159810.0       5766093.0                    52.0
# 82384                6159820.0       5766189.0                   116.0
# 82385                6159822.0       5766245.0                    59.0
# 82386                6159825.0       5766304.0                    63.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 81520                 NaN                            0.00
# 81521              7397.0                            0.08
# 81522             16160.0                            0.34
# 81523             25663.0                            0.82
# 81524             34976.0                            1.48
# ...                   ...                             ...
# 82382                46.0                          197.36
# 82383                36.0                          197.36
# 82384                50.0                          197.37
# 82385                52.0                          197.37
# 82386                54.0                          197.37
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 81520                           0.00                                 0.00
# 81521                           0.08                                 0.00
# 81522                           0.34                                 0.00
# 81523                           0.82                                 0.00
# 81524                           1.48                                 0.00
# ...                              ...                                  ...
# 82382                          71.15                                65.19
# 82383                          71.15                                65.19
# 82384                          71.15                                65.19
# 82385                          71.15                                65.19
# 82386                          71.15                                65.19
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 81520                         NaN                             NaN
# 81521                         NaN                           783.0
# 81522                         NaN                          1710.0
# 81523                         NaN                          2716.0
# 81524                         NaN                          3702.0
# ...                           ...                             ...
# 82382                       61.02                             5.0
# 82383                       61.02                             4.0
# 82384                       61.02                             5.0
# 82385                       61.02                             6.0
# 82386                       61.03                             6.0
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 81520                      NaN                                  NaN
# 81521                   7397.0                                0.078
# 81522                  16160.0                                0.171
# 81523                  25663.0                                0.272
# 81524                  34976.0                                0.370
# ...                        ...                                  ...
# 82382                      2.0                                0.000
# 82383                      2.0                                0.000
# 82384                      3.0                                0.000
# 82385                      3.0                                0.000
# 82386                      3.0                                0.000
#
# [867 rows x 16 columns]

# %% [markdown]
# Another way - since we're interested in all of the rows, we don't need the `loc`

# %%
vacc_df[vacc_df['location'] == 'Israel'].head(2)
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 81520   Israel      ISR  2020-12-19                75.0               71.0
# 81521   Israel      ISR  2020-12-20              7472.0             7468.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 81520                      4.0             NaN                     NaN
# 81521                      4.0             NaN                  7397.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 81520                 NaN                            0.00
# 81521              7397.0                            0.08
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 81520                           0.00                                  0.0
# 81521                           0.08                                  0.0
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 81520                         NaN                             NaN
# 81521                         NaN                           783.0
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 81520                      NaN                                  NaN
# 81521                   7397.0                                0.078

# %% [markdown]
# Another way - since the column name contains no spaces

# %%
vacc_df.loc[vacc_df.location == 'Israel'].head(2)
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 81520   Israel      ISR  2020-12-19                75.0               71.0
# 81521   Israel      ISR  2020-12-20              7472.0             7468.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 81520                      4.0             NaN                     NaN
# 81521                      4.0             NaN                  7397.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 81520                 NaN                            0.00
# 81521              7397.0                            0.08
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 81520                           0.00                                  0.0
# 81521                           0.08                                  0.0
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 81520                         NaN                             NaN
# 81521                         NaN                           783.0
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 81520                      NaN                                  NaN
# 81521                   7397.0                                0.078

# %% [markdown]
# ### Selection using `query`

# %%
vacc_df.query('location == "Israel"').head(2)
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 81520   Israel      ISR  2020-12-19                75.0               71.0
# 81521   Israel      ISR  2020-12-20              7472.0             7468.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 81520                      4.0             NaN                     NaN
# 81521                      4.0             NaN                  7397.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 81520                 NaN                            0.00
# 81521              7397.0                            0.08
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 81520                           0.00                                  0.0
# 81521                           0.08                                  0.0
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 81520                         NaN                             NaN
# 81521                         NaN                           783.0
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 81520                      NaN                                  NaN
# 81521                   7397.0                                0.078

# %% [markdown]
# ### Selection using more than one condition

# %%
two_countries = vacc_df[(vacc_df.location == 'Israel') | (vacc_df.location == 'Denmark')]

# %%
vacc_df[(vacc_df.location == 'Israel') & (vacc_df.total_vaccinations == 75)]
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 81520   Israel      ISR  2020-12-19                75.0               71.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 81520                      4.0             NaN                     NaN
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 81520                 NaN                             0.0
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 81520                            0.0                                  0.0
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 81520                         NaN                             NaN
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 81520                      NaN                                  NaN

# %% [markdown]
# ### <span style="color:blue"> Exercise:</span>
# > Select two countries using `Query`
# >
# > What is the length of `two_countries`? (How many rows?)

# %% [markdown]
# ### Selection using a variable

# %% [markdown]
# Find the country with the maximum vaccinations:

# %%
max_vacc = vacc_df['total_vaccinations'].max()
max_vacc
# Out:
# 13532617012.0

# %% [markdown]
# but is this correct?\
# What country has the maximum vaccinations?

# %%
vacc_df.query('total_vaccinations == @max_vacc')
# Out:
#        location  iso_code        date  total_vaccinations  people_vaccinated  \
# 184036    World  OWID_WRL  2024-01-07        1.353262e+10       5.630594e+09
#
#         people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 184036             5.177748e+09    2.802250e+09                     NaN
#
#         daily_vaccinations  total_vaccinations_per_hundred  \
# 184036                 NaN                          169.69
#
#         people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 184036                           70.6                                64.92
#
#         total_boosters_per_hundred  daily_vaccinations_per_million  \
# 184036                       35.14                             NaN
#
#         daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 184036                      NaN                                  NaN

# %% [markdown]
# This is the world.. we want the data without the world..

# %% [markdown]
# ### Selection using part of the string

# %%
vacc_df['location'].str.contains('Wo')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 186366    False
# 186367    False
# 186368    False
# 186369    False
# 186370    False
# Name: location, Length: 186371, dtype: bool

# %%
vacc_df[vacc_df['location'].str.contains('Wo')]
# Out:
#        location  iso_code        date  total_vaccinations  people_vaccinated  \
# 182905    World  OWID_WRL  2020-12-02        0.000000e+00       0.000000e+00
# 182906    World  OWID_WRL  2020-12-03        0.000000e+00       0.000000e+00
# 182907    World  OWID_WRL  2020-12-04        1.000000e+00       1.000000e+00
# 182908    World  OWID_WRL  2020-12-05        1.000000e+00       1.000000e+00
# 182909    World  OWID_WRL  2020-12-06        1.000000e+00       1.000000e+00
# ...         ...       ...         ...                 ...                ...
# 184032    World  OWID_WRL  2024-01-03        1.353260e+10       5.630594e+09
# 184033    World  OWID_WRL  2024-01-04        1.353261e+10       5.630594e+09
# 184034    World  OWID_WRL  2024-01-05        1.353262e+10       5.630594e+09
# 184035    World  OWID_WRL  2024-01-06        1.353262e+10       5.630594e+09
# 184036    World  OWID_WRL  2024-01-07        1.353262e+10       5.630594e+09
#
#         people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 182905                      NaN             NaN                     0.0
# 182906                      NaN             NaN                     1.0
# 182907                      NaN             NaN                     1.0
# 182908                      NaN             NaN                     1.0
# 182909                      NaN             NaN                     1.0
# ...                         ...             ...                     ...
# 184032             5.177748e+09    2.802230e+09                     NaN
# 184033             5.177748e+09    2.802241e+09                     NaN
# 184034             5.177748e+09    2.802249e+09                     NaN
# 184035             5.177748e+09    2.802250e+09                     NaN
# 184036             5.177748e+09    2.802250e+09                     NaN
#
#         daily_vaccinations  total_vaccinations_per_hundred  \
# 182905                 0.0                            0.00
# 182906                 1.0                            0.00
# 182907                 1.0                            0.00
# 182908                 1.0                            0.00
# 182909                 1.0                            0.00
# ...                    ...                             ...
# 184032                 NaN                          169.69
# 184033                 NaN                          169.69
# 184034                 NaN                          169.69
# 184035                 NaN                          169.69
# 184036                 NaN                          169.69
#
#         people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 182905                            0.0                                  NaN
# 182906                            0.0                                  NaN
# 182907                            0.0                                  NaN
# 182908                            0.0                                  NaN
# 182909                            0.0                                  NaN
# ...                               ...                                  ...
# 184032                           70.6                                64.92
# 184033                           70.6                                64.92
# 184034                           70.6                                64.92
# 184035                           70.6                                64.92
# 184036                           70.6                                64.92
#
#         total_boosters_per_hundred  daily_vaccinations_per_million  \
# 182905                         NaN                             0.0
# 182906                         NaN                             0.0
# 182907                         NaN                             0.0
# 182908                         NaN                             0.0
# 182909                         NaN                             0.0
# ...                            ...                             ...
# 184032                       35.14                             NaN
# 184033                       35.14                             NaN
# 184034                       35.14                             NaN
# 184035                       35.14                             NaN
# 184036                       35.14                             NaN
#
#         daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 182905                      0.0                                  0.0
# 182906                      1.0                                  0.0
# 182907                      1.0                                  0.0
# 182908                      1.0                                  0.0
# 182909                      1.0                                  0.0
# ...                         ...                                  ...
# 184032                      NaN                                  NaN
# 184033                      NaN                                  NaN
# 184034                      NaN                                  NaN
# 184035                      NaN                                  NaN
# 184036                      NaN                                  NaN
#
# [1132 rows x 16 columns]

# %% [markdown]
# Wait.. how do we know there aren't any other countries with `Wo` in their name?

# %%
vacc_df[vacc_df['location'].str.contains('Wo')]['location'].unique()
# Out:
# array(['World'], dtype=object)

# %% [markdown]
# ### Select using `!=`

# %% [markdown]
# Remove the world data:

# %%
vacc_df_noWorld = vacc_df.loc[vacc_df.location != 'World']
#len(vacc_df_noWorld)

# %%
vacc_df_noWorld.loc[vacc_df.location == 'World']
# Out:
# Empty DataFrame
# Columns: [location, iso_code, date, total_vaccinations, people_vaccinated, people_fully_vaccinated, total_boosters, daily_vaccinations_raw, daily_vaccinations, total_vaccinations_per_hundred, people_vaccinated_per_hundred, people_fully_vaccinated_per_hundred, total_boosters_per_hundred, daily_vaccinations_per_million, daily_people_vaccinated, daily_people_vaccinated_per_hundred]
# Index: []

# %%
len(vacc_df)
# Out:
# 186371

# %% [markdown]
# Find the country with the maximum vaccinations:

# %%
max_vacc = vacc_df_noWorld['total_vaccinations'].max()
max_vacc
# Out:
# 9084319350.0

# %%
vacc_df_noWorld.query('total_vaccinations == @max_vacc')
# Out:
#       location  iso_code        date  total_vaccinations  people_vaccinated  \
# 11064     Asia  OWID_ASI  2024-01-07        9.084319e+09       3.688364e+09
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 11064             3.461818e+09    1.811766e+09                     NaN
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 11064                 NaN                          192.41
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 11064                          78.12                                73.32
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 11064                       38.37                             NaN
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 11064                      NaN                                  NaN

# %% [markdown]
# ### <span style="color:blue"> Exercise:</span>

# %% [markdown]
# > Find the average `total_vaccinations` in `location=Asia`

# %% [markdown]
# ----
# ### <span style="color:blue"> Exercise:</span>

# %% [markdown]
# > Select the number of daily vaccinations in Israel on date 2021-02-06
# >
# > How many countries have more than 50000000 vaccinations?

# %% [markdown]
# ---
# ## Summary of the functions in this unit:
#
#
# >* `.index.values` - the row indexes of this part of the dataframes
# >* `.str.contains` - selects rows and columns that contain a string
# >* `.max` - maximum value
# >* `.mean` - average value
# >* `.count` - the number of rows that contain a value
# >* `len()` - dataframe length
