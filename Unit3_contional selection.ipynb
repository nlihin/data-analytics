# %% [markdown]
# # Unit 3 - Conditional selection

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.csv'
vacc_df = pd.read_csv(url)

# %% [markdown]
# ### Selection with one condition

# %% [markdown]
# Our condition: only data from Israel

# %%
vacc_df.loc[:,'location'] == 'Israel'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 157991    False
# 157992    False
# 157993    False
# 157994    False
# 157995    False
# Name: location, Length: 157996, dtype: bool

# %% [markdown]
# This creates a series of true/false
#
# We can insert this into the dataframe to select only that task:

# %%
vacc_df[vacc_df.loc[:,'location'] == 'Israel']
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 68378   Israel      ISR  2020-12-19                75.0               71.0
# 68379   Israel      ISR  2020-12-20              7471.0             7467.0
# 68380   Israel      ISR  2020-12-21             32394.0            32390.0
# 68381   Israel      ISR  2020-12-22             77062.0            77058.0
# 68382   Israel      ISR  2020-12-23            139981.0           139977.0
# ...        ...      ...         ...                 ...                ...
# 69175   Israel      ISR  2023-02-24          18642265.0          6722543.0
# 69176   Israel      ISR  2023-02-25          18642270.0          6722546.0
# 69177   Israel      ISR  2023-02-26          18642484.0          6722558.0
# 69178   Israel      ISR  2023-02-27          18642689.0          6722569.0
# 69179   Israel      ISR  2023-02-28          18642766.0          6722570.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 68378                      4.0             NaN                     NaN
# 68379                      4.0             NaN                  7396.0
# 68380                      4.0             NaN                 24923.0
# 68381                      4.0             NaN                 44668.0
# 68382                      4.0             NaN                 62919.0
# ...                        ...             ...                     ...
# 69175                6158848.0       5760874.0                    37.0
# 69176                6158848.0       5760876.0                     5.0
# 69177                6158868.0       5761058.0                   214.0
# 69178                6158893.0       5761227.0                   205.0
# 69179                6158907.0       5761289.0                    77.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 68378                 NaN                            0.00
# 68379              7396.0                            0.08
# 68380             16160.0                            0.34
# 68381             25662.0                            0.82
# 68382             34976.0                            1.48
# ...                   ...                             ...
# 69175               162.0                          197.29
# 69176               145.0                          197.29
# 69177               159.0                          197.30
# 69178               162.0                          197.30
# 69179               141.0                          197.30
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 68378                           0.00                                 0.00
# 68379                           0.08                                 0.00
# 68380                           0.34                                 0.00
# 68381                           0.82                                 0.00
# 68382                           1.48                                 0.00
# ...                              ...                                  ...
# 69175                          71.15                                65.18
# 69176                          71.15                                65.18
# 69177                          71.15                                65.18
# 69178                          71.15                                65.18
# 69179                          71.15                                65.18
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 68378                         NaN                             NaN
# 68379                         NaN                           783.0
# 68380                         NaN                          1710.0
# 68381                         NaN                          2716.0
# 68382                         NaN                          3702.0
# ...                           ...                             ...
# 69175                       60.97                            17.0
# 69176                       60.97                            15.0
# 69177                       60.97                            17.0
# 69178                       60.97                            17.0
# 69179                       60.97                            15.0
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 68378                      NaN                                  NaN
# 68379                   7396.0                                0.078
# 68380                  16160.0                                0.171
# 68381                  25662.0                                0.272
# 68382                  34976.0                                0.370
# ...                        ...                                  ...
# 69175                     11.0                                0.000
# 69176                     10.0                                0.000
# 69177                     11.0                                0.000
# 69178                     11.0                                0.000
# 69179                      6.0                                0.000
#
# [802 rows x 16 columns]

# %% [markdown]
# Another way - since we're interested in all of the rows, we don't need the `loc`

# %%
vacc_df[vacc_df['location'] == 'Israel'].head(2)
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 68378   Israel      ISR  2020-12-19                75.0               71.0
# 68379   Israel      ISR  2020-12-20              7471.0             7467.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 68378                      4.0             NaN                     NaN
# 68379                      4.0             NaN                  7396.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 68378                 NaN                            0.00
# 68379              7396.0                            0.08
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 68378                           0.00                                  0.0
# 68379                           0.08                                  0.0
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 68378                         NaN                             NaN
# 68379                         NaN                           783.0
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 68378                      NaN                                  NaN
# 68379                   7396.0                                0.078

# %% [markdown]
# Another way - since the column name contains no spaces

# %%
vacc_df.loc[vacc_df.location == 'Israel'].head(2)
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 68378   Israel      ISR  2020-12-19                75.0               71.0
# 68379   Israel      ISR  2020-12-20              7471.0             7467.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 68378                      4.0             NaN                     NaN
# 68379                      4.0             NaN                  7396.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 68378                 NaN                            0.00
# 68379              7396.0                            0.08
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 68378                           0.00                                  0.0
# 68379                           0.08                                  0.0
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 68378                         NaN                             NaN
# 68379                         NaN                           783.0
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 68378                      NaN                                  NaN
# 68379                   7396.0                                0.078

# %% [markdown]
# ### Selection using query `query`

# %%
vacc_df.query('location == "Israel"').head(2)
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 68378   Israel      ISR  2020-12-19                75.0               71.0
# 68379   Israel      ISR  2020-12-20              7471.0             7467.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 68378                      4.0             NaN                     NaN
# 68379                      4.0             NaN                  7396.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 68378                 NaN                            0.00
# 68379              7396.0                            0.08
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 68378                           0.00                                  0.0
# 68379                           0.08                                  0.0
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 68378                         NaN                             NaN
# 68379                         NaN                           783.0
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 68378                      NaN                                  NaN
# 68379                   7396.0                                0.078

# %% [markdown]
# ### Selection using more than one condition

# %%
two_countries = vacc_df[(vacc_df.location == 'Israel') | (vacc_df.location == 'Denmark')]
len(two_countries)
# Out:
# 1614

# %% [markdown]
# ### <span style="color:blue"> Exercise:</span>
# > Select two countries using `Query`
# >
# > What is the length of `two_countries`? (How many rows?)

# %% [markdown]
# ### Selection using a variable

# %% [markdown]
# Find the country with the maximum vaccinations:

# %%
max_vacc = vacc_df['total_vaccinations'].max()
max_vacc
# Out:
# 13312958715.0

# %% [markdown]
# but is this correct?\
# What country has the maximum vaccinations?

# %%
vacc_df.query('total_vaccinations == @max_vacc')
# Out:
#        location  iso_code        date  total_vaccinations  people_vaccinated  \
# 156078    World  OWID_WRL  2023-02-28        1.331296e+10       5.556363e+09
#
#         people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 156078             5.107791e+09    2.739484e+09                     NaN
#
#         daily_vaccinations  total_vaccinations_per_hundred  \
# 156078                 NaN                          166.93
#
#         people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 156078                          69.67                                64.05
#
#         total_boosters_per_hundred  daily_vaccinations_per_million  \
# 156078                       34.35                             NaN
#
#         daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 156078                      NaN                                  NaN

# %% [markdown]
# This is the world.. we want the data without the world..

# %% [markdown]
# ### Selection using part of the string

# %%
vacc_df['location'].str.contains('Wo')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 157991    False
# 157992    False
# 157993    False
# 157994    False
# 157995    False
# Name: location, Length: 157996, dtype: bool

# %%
vacc_df[vacc_df['location'].str.contains('Wo')]
# Out:
#        location  iso_code        date  total_vaccinations  people_vaccinated  \
# 155260    World  OWID_WRL  2020-12-02        0.000000e+00       0.000000e+00
# 155261    World  OWID_WRL  2020-12-03        0.000000e+00       0.000000e+00
# 155262    World  OWID_WRL  2020-12-04        1.000000e+00       1.000000e+00
# 155263    World  OWID_WRL  2020-12-05        1.000000e+00       1.000000e+00
# 155264    World  OWID_WRL  2020-12-06        1.000000e+00       1.000000e+00
# ...         ...       ...         ...                 ...                ...
# 156074    World  OWID_WRL  2023-02-24        1.331029e+10       5.555324e+09
# 156075    World  OWID_WRL  2023-02-25        1.331061e+10       5.555342e+09
# 156076    World  OWID_WRL  2023-02-26        1.331260e+10       5.556292e+09
# 156077    World  OWID_WRL  2023-02-27        1.331266e+10       5.556296e+09
# 156078    World  OWID_WRL  2023-02-28        1.331296e+10       5.556363e+09
#
#         people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 155260                      NaN             NaN                     0.0
# 155261                      NaN             NaN                     1.0
# 155262                      NaN             NaN                     1.0
# 155263                      NaN             NaN                     1.0
# 155264                      NaN             NaN                     1.0
# ...                         ...             ...                     ...
# 156074             5.106773e+09    2.738176e+09                     NaN
# 156075             5.106896e+09    2.738352e+09                     NaN
# 156076             5.107729e+09    2.739255e+09                     NaN
# 156077             5.107735e+09    2.739311e+09                     NaN
# 156078             5.107791e+09    2.739484e+09                     NaN
#
#         daily_vaccinations  total_vaccinations_per_hundred  \
# 155260                 0.0                            0.00
# 155261                 1.0                            0.00
# 155262                 1.0                            0.00
# 155263                 1.0                            0.00
# 155264                 1.0                            0.00
# ...                    ...                             ...
# 156074                 NaN                          166.90
# 156075                 NaN                          166.90
# 156076                 NaN                          166.93
# 156077                 NaN                          166.93
# 156078                 NaN                          166.93
#
#         people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 155260                           0.00                                  NaN
# 155261                           0.00                                  NaN
# 155262                           0.00                                  NaN
# 155263                           0.00                                  NaN
# 155264                           0.00                                  NaN
# ...                               ...                                  ...
# 156074                          69.66                                64.03
# 156075                          69.66                                64.04
# 156076                          69.67                                64.05
# 156077                          69.67                                64.05
# 156078                          69.67                                64.05
#
#         total_boosters_per_hundred  daily_vaccinations_per_million  \
# 155260                         NaN                             0.0
# 155261                         NaN                             0.0
# 155262                         NaN                             0.0
# 155263                         NaN                             0.0
# 155264                         NaN                             0.0
# ...                            ...                             ...
# 156074                       34.33                             NaN
# 156075                       34.34                             NaN
# 156076                       34.35                             NaN
# 156077                       34.35                             NaN
# 156078                       34.35                             NaN
#
#         daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 155260                      0.0                                  0.0
# 155261                      1.0                                  0.0
# 155262                      1.0                                  0.0
# 155263                      1.0                                  0.0
# 155264                      1.0                                  0.0
# ...                         ...                                  ...
# 156074                      NaN                                  NaN
# 156075                      NaN                                  NaN
# 156076                      NaN                                  NaN
# 156077                      NaN                                  NaN
# 156078                      NaN                                  NaN
#
# [819 rows x 16 columns]

# %% [markdown]
# Wait.. how do we know there aren't any other countries with `Wo` in their name?

# %%
vacc_df[vacc_df['location'].str.contains('Wo')]['location'].unique()
# Out:
# array(['World'], dtype=object)

# %% [markdown]
# ### Select using `!=`

# %% [markdown]
# Remove the world data:

# %%
vacc_df_noWorld = vacc_df.loc[vacc_df.location != 'World']
#len(vacc_df_noWorld)

# %%
vacc_df_noWorld.loc[vacc_df.location == 'World']
# Out:
# Empty DataFrame
# Columns: [location, iso_code, date, total_vaccinations, people_vaccinated, people_fully_vaccinated, total_boosters, daily_vaccinations_raw, daily_vaccinations, total_vaccinations_per_hundred, people_vaccinated_per_hundred, people_fully_vaccinated_per_hundred, total_boosters_per_hundred, daily_vaccinations_per_million, daily_people_vaccinated, daily_people_vaccinated_per_hundred]
# Index: []

# %%
len(vacc_df)
# Out:
# 157996

# %% [markdown]
# Find the country with the maximum vaccinations:

# %%
max_vacc = vacc_df_noWorld['total_vaccinations'].max()
max_vacc
# Out:
# 8987651826.0

# %%
vacc_df_noWorld.query('total_vaccinations == @max_vacc')
# Out:
#      location  iso_code        date  total_vaccinations  people_vaccinated  \
# 8343     Asia  OWID_ASI  2023-02-28        8.987652e+09       3.665997e+09
#
#       people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 8343             3.432526e+09    1.781602e+09                     NaN
#
#       daily_vaccinations  total_vaccinations_per_hundred  \
# 8343                 NaN                          190.36
#
#       people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 8343                          77.65                                 72.7
#
#       total_boosters_per_hundred  daily_vaccinations_per_million  \
# 8343                       37.73                             NaN
#
#       daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 8343                      NaN                                  NaN

# %% [markdown]
# ### <span style="color:blue"> Exercise:</span>

# %% [markdown]
# > Find the average `total_vaccinations` in `location=Asia`

# %% [markdown]
# ----
# ### <span style="color:blue"> Exercise:</span>

# %% [markdown]
# > Select the number of daily vaccinations in Israel on date 2021-02-06
# >
# > How many countries have more than 50000000 vaccinations?

# %% [markdown]
# ---
# ## Summary of the functions in this unit:
#
#
# >* `.index.values` - the row indexes of this part of the dataframes
# >* `.str.contains` - selects rows and columns that contain a string
# >* `.max` - maximum value
# >* `.mean` - average value
# >* `.count` - the number of rows that contain a value
# >* `len()` - dataframe length
