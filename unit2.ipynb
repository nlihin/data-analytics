# %% [markdown]
# # Unit 2
# ---
#
#
#
#
# 1. [Introducing Pandas](#section1)
# 2. [Reading files](#section2)
# 3. [Selecting data](#section3)
# 4. [Describe the data](#section4)
# 5. [Conditional selection](#section5)

# %% [markdown]
# <a id='section1'></a>

# %% [markdown]
# ## 1. Introducing Pandas
# ---
#
# <div>
# <img src="images/pandas.JPG" width="400"/>
# </div>
#
#
#
# [Panda's documentation](https://pandas.pydata.org/pandas-docs/stable/)

# %% [markdown]
# To begin we need to import pandas
# When you see pd, know it is referring to pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Pandas is a popular Python library used for working in tabular data (similar to the data stored in a spreadsheet).
#
# There are two main data structure used by pandas
# - Series: equivalent to a vector or a list
# - Dataframe: equivalent to a table.
#
# Each column in a pandas Dataframe is a pandas Series data structure. We will mainly be looking at the Dataframe.
#
# We can easily create a Pandas Dataframe by reading a .csv file

# %% [markdown]
# <a id='section2'></a>

# %% [markdown]
# ## 2. Reading files
# ---
#
# <div>
# <img src="images/reading.PNG" width="400"/>
# </div>
#
#
# We will read the whole file at once using Pandas.
# Sometimes you might want to read the file line by line, and process each line. Thats possible of course. See for example [here.](https://www.geeksforgeeks.org/read-a-file-line-by-line-in-python/)
#
# We will read data on [COVID-19 vaccinations](https://github.com/owid/covid-19-data/tree/master/public/data/vaccinations)
#
# In order to do that, I retrieved the raw data's url
#
# Press on raw either here:
#
# <div>
# <img src="images/raw.png" width="800"/>
# </div>
#
# or here:
#
# <div>
# <img src="images/unit1_raw2.jpg" width="800"/>
# </div>
#
# and retrieve the link:
#
# <div>
# <img src="images/unit1_raw3.jpg" width="800"/>
# </div>

# %%
url = 'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.csv'
vacc_df = pd.read_csv(url)

# %% [markdown]
# read_csv has about 30 different options. See the
# [documentation](https://pandas.pydata.org/pandasdocs/stable/reference/api/pandas.read_csv.html#pandas.read_csv)
#
# For example, sep='\t' is used for tab delimited files and 'usecol' reads only specific columns.

# %%
type(vacc_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# view the shape of the dataframe:

# %%
vacc_df.shape
# Out:
# (86936, 16)

# %% [markdown]
# view basic information:

# %%
vacc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86936 entries, 0 to 86935
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             86936 non-null  object
#  1   iso_code                             86936 non-null  object
#  2   date                                 86936 non-null  object
#  3   total_vaccinations                   46986 non-null  float64
#  4   people_vaccinated                    44755 non-null  float64
#  5   people_fully_vaccinated              42027 non-null  float64
#  6   total_boosters                       18202 non-null  float64
#  7   daily_vaccinations_raw               39169 non-null  float64
#  8   daily_vaccinations                   86659 non-null  float64
#  9   total_vaccinations_per_hundred       46986 non-null  float64
#  10  people_vaccinated_per_hundred        44755 non-null  float64
#  11  people_fully_vaccinated_per_hundred  42027 non-null  float64
#  12  total_boosters_per_hundred           18202 non-null  float64
#  13  daily_vaccinations_per_million       86659 non-null  float64
#  14  daily_people_vaccinated              85355 non-null  float64
#  15  daily_people_vaccinated_per_hundred  85355 non-null  float64
# dtypes: float64(13), object(3)
# memory usage: 10.6+ MB

# %%
vacc_df.columns
# Out:
# Index(['location', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'daily_vaccinations_per_million', 'daily_people_vaccinated',
#        'daily_people_vaccinated_per_hundred'],
#       dtype='object')

# %% [markdown]
# View the first few rows:

# %%
vacc_df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                             0.0
# 1              1367.0                             NaN
# 2              1367.0                             NaN
# 3              1367.0                             NaN
# 4              1367.0                             NaN
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                            0.0                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    total_boosters_per_hundred  daily_vaccinations_per_million  \
# 0                         NaN                             NaN
# 1                         NaN                            34.0
# 2                         NaN                            34.0
# 3                         NaN                            34.0
# 4                         NaN                            34.0
#
#    daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 0                      NaN                                  NaN
# 1                   1367.0                                0.003
# 2                   1367.0                                0.003
# 3                   1367.0                                0.003
# 4                   1367.0                                0.003

# %% [markdown]
# What do you think that the 'tail' command does? Try it out!
#
# What happens if we just type vacc_df, without a head or a tail?

# %%
vacc_df.tail()
# Out:
#        location iso_code        date  total_vaccinations  people_vaccinated  \
# 35158  Zimbabwe      ZWE  2021-07-17           1771434.0          1132045.0
# 35159  Zimbabwe      ZWE  2021-07-18           1785533.0          1144379.0
# 35160  Zimbabwe      ZWE  2021-07-19           1827638.0          1184435.0
# 35161  Zimbabwe      ZWE  2021-07-20           1897337.0          1247494.0
# 35162  Zimbabwe      ZWE  2021-07-21           1949472.0          1292642.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 35158                 639389.0                 39694.0             41958.0
# 35159                 641154.0                 14099.0             42019.0
# 35160                 643203.0                 42105.0             42253.0
# 35161                 649843.0                 69699.0             45971.0
# 35162                 656830.0                 52135.0             47976.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 35158                           11.92                           7.62
# 35159                           12.01                           7.70
# 35160                           12.30                           7.97
# 35161                           12.77                           8.39
# 35162                           13.12                           8.70
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 35158                                 4.30                          2823.0
# 35159                                 4.31                          2827.0
# 35160                                 4.33                          2843.0
# 35161                                 4.37                          3093.0
# 35162                                 4.42                          3228.0

# %% [markdown]
# ---
# A summary of the functions so far:
#
# >* `pd.read_csv` - Read data from a CSV file into a Pandas `DataFrame` object
# >* `.info()` - View basic infomation about rows, columns & data types
# >* `.columns` - Get the list of column names
# >* `.shape` - Get the number of rows & columns as a tuple
# >* `.head()`, `.tail()` - View the beginning/end of the file

# %% [markdown]
# <a id='section3'></a>

# %% [markdown]
# ---
# ## 3. Selecting data
#
# ![](https://i.imgur.com/zfxLzEv.png)

# %% [markdown]
# ##### Pandas format is similar to a dictionary, not to a list
#
# a list:

# %%
covid_data_list = [
    {'date': '2020-08-30', 'new_cases': 1444, 'new_deaths': 1, 'new_tests': 53541},
    {'date': '2020-08-31', 'new_cases': 1365, 'new_deaths': 4, 'new_tests': 42583},
    {'date': '2020-09-01', 'new_cases': 996, 'new_deaths': 6, 'new_tests': 54395},
    {'date': '2020-09-02', 'new_cases': 975, 'new_deaths': 8 },
    {'date': '2020-09-03', 'new_cases': 1326, 'new_deaths': 6},
]
covid_data_list
# Out:
# [{'date': '2020-08-30',
#   'new_cases': 1444,
#   'new_deaths': 1,
#   'new_tests': 53541},
#  {'date': '2020-08-31',
#   'new_cases': 1365,
#   'new_deaths': 4,
#   'new_tests': 42583},
#  {'date': '2020-09-01', 'new_cases': 996, 'new_deaths': 6, 'new_tests': 54395},
#  {'date': '2020-09-02', 'new_cases': 975, 'new_deaths': 8},
#  {'date': '2020-09-03', 'new_cases': 1326, 'new_deaths': 6}]

# %% [markdown]
# a dictionary:

# %%
covid_data_dict = {
    'date':       ['2020-08-30', '2020-08-31', '2020-09-01', '2020-09-02', '2020-09-03'],
    'new_cases':  [1444, 1365, 996, 975, 1326],
    'new_deaths': [1, 4, 6, 8, 6],
    'new_tests': [53541, 42583, 54395, None, None]
}

# %% [markdown]
# #### The index of a dataframe doesn't have to be numeric

# %%
df = pd.DataFrame({'age':[30, 2, 12, 4, 32, 33, 69],
                   'color':['blue', 'green', 'red', 'white', 'gray', 'black', 'red'],
                   'food':['Steak', 'Lamb', 'Mango', 'Apple', 'Cheese', 'Melon', 'Beans'],
                   'height':[165, 70, 120, 80, 180, 172, 150],
                   'score':[4.6, 8.3, 9.0, 3.3, 1.8, 9.5, 2.2],
                   'state':['NY', 'TX', 'FL', 'AL', 'AK', 'TX', 'TX']
                   },
                  index=['Jane', 'Nick', 'Aaron', 'Penelope', 'Dean', 'Christina', 'Cornelia'])
df
# Out:
#            age  color    food  height  score state
# Jane        30   blue   Steak     165    4.6    NY
# Nick         2  green    Lamb      70    8.3    TX
# Aaron       12    red   Mango     120    9.0    FL
# Penelope     4  white   Apple      80    3.3    AL
# Dean        32   gray  Cheese     180    1.8    AK
# Christina   33  black   Melon     172    9.5    TX
# Cornelia    69    red   Beans     150    2.2    TX

# %% [markdown]
# In our our file the index is numeric:

# %%
vacc_df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                             0.0
# 1              1367.0                             NaN
# 2              1367.0                             NaN
# 3              1367.0                             NaN
# 4              1367.0                             NaN
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                            0.0                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    total_boosters_per_hundred  daily_vaccinations_per_million  \
# 0                         NaN                             NaN
# 1                         NaN                            34.0
# 2                         NaN                            34.0
# 3                         NaN                            34.0
# 4                         NaN                            34.0
#
#    daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 0                      NaN                                  NaN
# 1                   1367.0                                0.003
# 2                   1367.0                                0.003
# 3                   1367.0                                0.003
# 4                   1367.0                                0.003

# %% [markdown]
# return a single column as a series:

# %% [markdown]
# note: using the `.` notation is possible only for columns whose names do not contain spaces or special characters.

# %%
vacc_df.location
vacc_df['location']
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 86931       Zimbabwe
# 86932       Zimbabwe
# 86933       Zimbabwe
# 86934       Zimbabwe
# 86935       Zimbabwe
# Name: location, Length: 86936, dtype: object

# %%
type(vacc_df.location)
# Out:
# pandas.core.series.Series

# %% [markdown]
# return a single column as a dataframe:

# %%
vacc_df[['location']]
# Out:
#           location
# 0      Afghanistan
# 1      Afghanistan
# 2      Afghanistan
# 3      Afghanistan
# 4      Afghanistan
# ...            ...
# 86931     Zimbabwe
# 86932     Zimbabwe
# 86933     Zimbabwe
# 86934     Zimbabwe
# 86935     Zimbabwe
#
# [86936 rows x 1 columns]

# %% [markdown]
# retrieve a specific cell

# %%
vacc_df.location[600]
# Out:
# 'Africa'

# %% [markdown]
# retrieve two columns

# %%
vacc_df[['location','date']]
# Out:
#           location        date
# 0      Afghanistan  2021-02-22
# 1      Afghanistan  2021-02-23
# 2      Afghanistan  2021-02-24
# 3      Afghanistan  2021-02-25
# 4      Afghanistan  2021-02-26
# ...            ...         ...
# 86931     Zimbabwe  2022-03-01
# 86932     Zimbabwe  2022-03-02
# 86933     Zimbabwe  2022-03-03
# 86934     Zimbabwe  2022-03-04
# 86935     Zimbabwe  2022-03-05
#
# [86936 rows x 2 columns]

# %% [markdown]
# #### Seletcting subsets of rows and columns
#
# One way to do that is iloc.
#
# `.iloc` - selects subsets of rows and columns by integer location only

# %%
vacc_df.iloc[0]  #first row as a series
vacc_df.iloc[0:1]  #first row as a dataframe
vacc_df.iloc[-1] #last row as a series
vacc_df.iloc[-1:] #last row as a dataframe
# Out:
#        location iso_code        date  total_vaccinations  people_vaccinated  \
# 86935  Zimbabwe      ZWE  2022-03-05           7936145.0          4377373.0
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 86935                3410340.0        148432.0                  5524.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 86935              8458.0                           52.58
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 86935                           29.0                                 22.6
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 86935                        0.98                           560.0
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 86935                   2776.0                                0.018

# %% [markdown]
# The : operator
#
#  - when used alone it means "everything"
#
# - also used to indicate a ***slice*** of values

# %%
vacc_df.iloc[2:4] # second and third row
vacc_df.iloc[[-1,2,22]] #a few specific rows

# Columns:
vacc_df.iloc[:,0] # first column of data frame  
vacc_df.iloc[:,1] # second column of data frame  
vacc_df.iloc[:,-1] # last column of data frame

#Rows and columns
vacc_df.iloc[0:5] # first five rows of dataframe
vacc_df.iloc[:, 0:2] # first two columns of data frame with all rows
vacc_df.iloc[[0,3,6,24], [0,5,6]] # 1st, 4th, 7th, 25th row + 1st 6th 7th columns.
# Out:
#        location  people_fully_vaccinated  total_boosters
# 0   Afghanistan                      NaN             NaN
# 3   Afghanistan                      NaN             NaN
# 6   Afghanistan                      NaN             NaN
# 24  Afghanistan                      NaN             NaN

# %% [markdown]
# What if I want to select the 'daily_vaccinations' column, but I don't remember the column number?

# %% [markdown]
# Use `.loc`
#
# `.loc` - selects subsets of rows and columns by label only. Allowed inputs are:
#
# - A single label, e.g. 5 or 'a', (note that 5 is interpreted as a label of the index, and never as an integer position along the index).
#
# - A list or array of labels, e.g. ['a', 'b', 'c'].
#
# - A slice object with labels, e.g. 'a':'f'.

# %%
vacc_df.loc[2:3,['daily_vaccinations','date']]
# Out:
#    daily_vaccinations        date
# 2              1367.0  2021-02-24
# 3              1367.0  2021-02-25

# %% [markdown]
# I'm missing the location. Let's add it.

# %%
vacc_df.loc[0:3,['location','daily_vaccinations','date']]
# Out:
#       location  daily_vaccinations        date
# 0  Afghanistan                 NaN  2021-02-22
# 1  Afghanistan              1367.0  2021-02-23
# 2  Afghanistan              1367.0  2021-02-24
# 3  Afghanistan              1367.0  2021-02-25

# %% [markdown]
# Semantics are similar to iloc. But note:
#
# - `iloc` excludes the last element.  `df.iloc[0:1000]` will return entries 0...999
# - `loc`, includes the last element.  `df.loc[0:1000]` will return entries 0...1000
#
# you try it! What is the difference between:
#
# > vacc_df.iloc[0:5]
#
# > vacc_df.loc[0:5]

# %%
 vacc_df.iloc[0:5]
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %%
vacc_df.loc[0:5]
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
# 5  Afghanistan      AFG  2021-02-27                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
# 5                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
# 5                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0
# 5                                  NaN                            35.0

# %% [markdown]
# ---
# ---
#
# Now you:
#
# what do you do to select:
#
# a. first five rows?
#
# b. first two columns, all rows?
#
# c. 1st and 3rd row and 2nd and 4th column?
#
# ---

# %%
vacc_df.iloc [:,0:2]
# Out:
#           location iso_code
# 0      Afghanistan      AFG
# 1      Afghanistan      AFG
# 2      Afghanistan      AFG
# 3      Afghanistan      AFG
# 4      Afghanistan      AFG
# ...            ...      ...
# 35158     Zimbabwe      ZWE
# 35159     Zimbabwe      ZWE
# 35160     Zimbabwe      ZWE
# 35161     Zimbabwe      ZWE
# 35162     Zimbabwe      ZWE
#
# [35163 rows x 2 columns]

# %% [markdown]
# ---
# A summary of the functions in this unit:
#
# >* `.iloc` - selects rows and columns by integer location
# >* `.loc` - selects rows and columns by label location

# %% [markdown]
# Note: indexing operators as the ones working on dictionaries, will also work in pandas. But for more advanced operations, better get used to loc and iloc.
#
# ---

# %% [markdown]
# <a id='section4'></a>

# %% [markdown]
# ## 4. Describe the data:

# %% [markdown]
# Describe the data

# %%
vacc_df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        4.698600e+04       4.475500e+04             4.202700e+04
# mean         1.670557e+08       8.545837e+07             6.719376e+07
# std          7.654004e+08       3.929743e+08             3.238892e+08
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          6.488112e+05       4.100280e+05             2.854980e+05
# 50%          4.766018e+06       2.862765e+06             2.214907e+06
# 75%          2.909507e+07       1.702983e+07             1.350290e+07
# max          1.088133e+10       4.986748e+09             4.414217e+09
#
#        total_boosters  daily_vaccinations_raw  daily_vaccinations  \
# count    1.820200e+04            3.916900e+04        8.665900e+04
# mean     1.884933e+07            1.124142e+06        5.122924e+05
# std      9.005282e+07            4.280085e+06        2.779368e+06
# min      1.000000e+00            0.000000e+00        0.000000e+00
# 25%      2.978000e+03            6.495000e+03        1.121000e+03
# 50%      4.964770e+05            3.885600e+04        9.646000e+03
# 75%      4.003726e+06            2.632070e+05        6.583800e+04
# max      1.429801e+09            5.490639e+07        4.353698e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    46986.000000                   44755.000000
# mean                        74.578996                      38.725218
# std                         64.948555                      28.964507
# min                          0.000000                       0.000000
# 25%                         12.990000                       9.255000
# 50%                         61.050000                      38.010000
# 75%                        126.080000                      65.630000
# max                        336.160000                     124.650000
#
#        people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# count                         42027.000000                18202.000000
# mean                             33.077047                   13.063171
# std                              27.837182                   17.794349
# min                               0.000000                    0.000000
# 25%                               5.290000                    0.010000
# 50%                              28.030000                    3.590000
# 75%                              58.835000                   21.820000
# max                             121.530000                   89.990000
#
#        daily_vaccinations_per_million  daily_people_vaccinated  \
# count                    86659.000000             8.535500e+04
# mean                      3337.479535             2.112457e+05
# std                       3895.063352             1.172379e+06
# min                          0.000000             0.000000e+00
# 25%                        702.000000             4.450000e+02
# 50%                       2232.000000             4.016000e+03
# 75%                       4818.000000             2.682600e+04
# max                     117497.000000             2.141905e+07
#
#        daily_people_vaccinated_per_hundred
# count                         85355.000000
# mean                              0.149874
# std                               0.245209
# min                               0.000000
# 25%                               0.024000
# 50%                               0.073000
# 75%                               0.192000
# max                              11.750000

# %% [markdown]
# a note on e: e stands for exponent of 10, and it's always followed by another number, which is the value of the exponent
#
# 10e + 1 = 100
#
# 10e + 2 = 1000

# %% [markdown]
# describe categorical data:

# %%
vacc_df[['location']].describe()
# Out:
#            location
# count         86936
# unique          235
# top     High income
# freq            460

# %% [markdown]
# `High income` is not a location, we have a few of these here. Also have `Africa`, `World` and some others

# %% [markdown]
# <a id='section5'></a>

# %% [markdown]
# ## 5. Conditional selection

# %%
vacc_df.loc[:,'location'] == 'Israel'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 86931    False
# 86932    False
# 86933    False
# 86934    False
# 86935    False
# Name: location, Length: 86936, dtype: bool

# %% [markdown]
# This creates a series of true/false
#
# We can insert this into the dataframe to select only that task:

# %%
vacc_df[vacc_df.loc[:,'location'] == 'Israel']
# Out:
#       location  iso_code        date  total_vaccinations  people_vaccinated  \
# 85467    World  OWID_WRL  2020-12-02        0.000000e+00       0.000000e+00
# 85468    World  OWID_WRL  2020-12-03        0.000000e+00       0.000000e+00
# 85469    World  OWID_WRL  2020-12-04        1.000000e+00       1.000000e+00
# 85470    World  OWID_WRL  2020-12-05        1.000000e+00       1.000000e+00
# 85471    World  OWID_WRL  2020-12-06        1.000000e+00       1.000000e+00
# ...        ...       ...         ...                 ...                ...
# 85922    World  OWID_WRL  2022-03-02        1.074307e+10       4.975229e+09
# 85923    World  OWID_WRL  2022-03-03        1.075692e+10       4.976451e+09
# 85924    World  OWID_WRL  2022-03-04        1.076896e+10       4.978811e+09
# 85925    World  OWID_WRL  2022-03-05        1.078704e+10       4.982569e+09
# 85926    World  OWID_WRL  2022-03-06        1.088133e+10       4.986748e+09
#
#        people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 85467                      NaN             NaN                     0.0
# 85468                      NaN             NaN                     0.0
# 85469                      NaN             NaN                     0.0
# 85470                      NaN             NaN                     0.0
# 85471                      NaN             NaN                     0.0
# ...                        ...             ...                     ...
# 85922             4.393554e+09    1.403893e+09              24458817.0
# 85923             4.399052e+09    1.407711e+09              25001449.0
# 85924             4.402673e+09    1.410391e+09              23182834.0
# 85925             4.408999e+09    1.413665e+09              21699233.0
# 85926             4.414217e+09    1.429801e+09              18393589.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 85467                 0.0                            0.00
# 85468                 0.0                            0.00
# 85469                 0.0                            0.00
# 85470                 0.0                            0.00
# 85471                 0.0                            0.00
# ...                   ...                             ...
# 85922          22845824.0                          136.42
# 85923          21837931.0                          136.60
# 85924          20749352.0                          136.75
# 85925          19892930.0                          136.98
# 85926          19204971.0                          138.18
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 85467                           0.00                                  NaN
# 85468                           0.00                                  NaN
# 85469                           0.00                                  NaN
# 85470                           0.00                                  NaN
# 85471                           0.00                                  NaN
# ...                              ...                                  ...
# 85922                          63.18                                55.79
# 85923                          63.19                                55.86
# 85924                          63.22                                55.91
# 85925                          63.27                                55.99
# 85926                          63.32                                56.05
#
#        total_boosters_per_hundred  daily_vaccinations_per_million  \
# 85467                         NaN                             0.0
# 85468                         NaN                             0.0
# 85469                         NaN                             0.0
# 85470                         NaN                             0.0
# 85471                         NaN                             0.0
# ...                           ...                             ...
# 85922                       17.83                          2901.0
# 85923                       17.88                          2773.0
# 85924                       17.91                          2635.0
# 85925                       17.95                          2526.0
# 85926                       18.16                          2439.0
#
#        daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 85467                      0.0                                0.000
# 85468                      0.0                                0.000
# 85469                      0.0                                0.000
# 85470                      0.0                                0.000
# 85471                      0.0                                0.000
# ...                        ...                                  ...
# 85922                6233023.0                                0.079
# 85923                5654484.0                                0.072
# 85924                5204433.0                                0.066
# 85925                4665358.0                                0.059
# 85926                4272886.0                                0.054
#
# [460 rows x 16 columns]

# %% [markdown]
# Another way:

# %%
vacc_df.loc[vacc_df.location == 'Israel']
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 15458   Israel      ISR  2020-12-19                60.0               60.0
# 15459   Israel      ISR  2020-12-20              7434.0             7434.0
# 15460   Israel      ISR  2020-12-21             32318.0            32318.0
# 15461   Israel      ISR  2020-12-22             76933.0            76933.0
# 15462   Israel      ISR  2020-12-23            139765.0           139765.0
# ...        ...      ...         ...                 ...                ...
# 15669   Israel      ISR  2021-07-18          10980188.0          5744452.0
# 15670   Israel      ISR  2021-07-19          10994393.0          5747537.0
# 15671   Israel      ISR  2021-07-20          11008624.0          5750067.0
# 15672   Israel      ISR  2021-07-21          11022474.0          5752297.0
# 15673   Israel      ISR  2021-07-22          11038265.0          5755067.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 15458                      NaN                     NaN                 NaN
# 15459                      NaN                  7374.0              7374.0
# 15460                      NaN                 24884.0             16129.0
# 15461                      NaN                 44615.0             25624.0
# 15462                      NaN                 62832.0             34926.0
# ...                        ...                     ...                 ...
# 15669                5235736.0                 11665.0              7985.0
# 15670                5246856.0                 14205.0              9183.0
# 15671                5258557.0                 14231.0             10060.0
# 15672                5270177.0                 13850.0             10620.0
# 15673                5283198.0                 15791.0             11172.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 15458                            0.00                           0.00
# 15459                            0.09                           0.09
# 15460                            0.37                           0.37
# 15461                            0.89                           0.89
# 15462                            1.61                           1.61
# ...                               ...                            ...
# 15669                          126.86                          66.37
# 15670                          127.02                          66.40
# 15671                          127.19                          66.43
# 15672                          127.35                          66.46
# 15673                          127.53                          66.49
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 15458                                  NaN                             NaN
# 15459                                  NaN                           852.0
# 15460                                  NaN                          1863.0
# 15461                                  NaN                          2960.0
# 15462                                  NaN                          4035.0
# ...                                    ...                             ...
# 15669                                60.49                           923.0
# 15670                                60.62                          1061.0
# 15671                                60.75                          1162.0
# 15672                                60.89                          1227.0
# 15673                                61.04                          1291.0
#
# [216 rows x 12 columns]

# %% [markdown]
# Select two countries:

# %%
two_countries = vacc_df.loc[(vacc_df.location == 'Israel') | (vacc_df.location == 'Denmark')]
two_countries.head()
# Out:
#      location iso_code        date  total_vaccinations  people_vaccinated  \
# 8047  Denmark      DNK  2020-12-17                 1.0                1.0
# 8048  Denmark      DNK  2020-12-18                 2.0                2.0
# 8049  Denmark      DNK  2020-12-19                 3.0                3.0
# 8050  Denmark      DNK  2020-12-20                 NaN                NaN
# 8051  Denmark      DNK  2020-12-21                 4.0                4.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 8047                      NaN                     NaN                 NaN
# 8048                      NaN                     1.0                 1.0
# 8049                      NaN                     1.0                 1.0
# 8050                      NaN                     NaN                 1.0
# 8051                      NaN                     NaN                 1.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 8047                             0.0                            0.0
# 8048                             0.0                            0.0
# 8049                             0.0                            0.0
# 8050                             NaN                            NaN
# 8051                             0.0                            0.0
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 8047                                  NaN                             NaN
# 8048                                  NaN                             0.0
# 8049                                  NaN                             0.0
# 8050                                  NaN                             0.0
# 8051                                  NaN                             0.0

# %% [markdown]
# only the indexs of the tasks:

# %%
two_countries.index.values
# Out:
# array([ 8047,  8048,  8049,  8050,  8051,  8052,  8053,  8054,  8055,
#         8056,  8057,  8058,  8059,  8060,  8061,  8062,  8063,  8064,
#         8065,  8066,  8067,  8068,  8069,  8070,  8071,  8072,  8073,
#         8074,  8075,  8076,  8077,  8078,  8079,  8080,  8081,  8082,
#         8083,  8084,  8085,  8086,  8087,  8088,  8089,  8090,  8091,
#         8092,  8093,  8094,  8095,  8096,  8097,  8098,  8099,  8100,
#         8101,  8102,  8103,  8104,  8105,  8106,  8107,  8108,  8109,
#         8110,  8111,  8112,  8113,  8114,  8115,  8116,  8117,  8118,
#         8119,  8120,  8121,  8122,  8123,  8124,  8125,  8126,  8127,
#         8128,  8129,  8130,  8131,  8132,  8133,  8134,  8135,  8136,
#         8137,  8138,  8139,  8140,  8141,  8142,  8143,  8144,  8145,
#         8146,  8147,  8148,  8149,  8150,  8151,  8152,  8153,  8154,
#         8155,  8156,  8157,  8158,  8159,  8160,  8161,  8162,  8163,
#         8164,  8165,  8166,  8167,  8168,  8169,  8170,  8171,  8172,
#         8173,  8174,  8175,  8176,  8177,  8178,  8179,  8180,  8181,
#         8182,  8183,  8184,  8185,  8186,  8187,  8188,  8189,  8190,
#         8191,  8192,  8193,  8194,  8195,  8196,  8197,  8198,  8199,
#         8200,  8201,  8202,  8203,  8204,  8205,  8206,  8207,  8208,
#         8209,  8210,  8211,  8212,  8213,  8214,  8215,  8216,  8217,
#         8218,  8219,  8220,  8221,  8222,  8223,  8224,  8225,  8226,
#         8227,  8228,  8229,  8230,  8231,  8232,  8233,  8234,  8235,
#         8236,  8237,  8238,  8239,  8240,  8241,  8242,  8243,  8244,
#         8245,  8246,  8247,  8248,  8249,  8250,  8251,  8252,  8253,
#         8254,  8255,  8256,  8257,  8258,  8259,  8260,  8261,  8262,
#         8263, 15458, 15459, 15460, 15461, 15462, 15463, 15464, 15465,
#        15466, 15467, 15468, 15469, 15470, 15471, 15472, 15473, 15474,
#        15475, 15476, 15477, 15478, 15479, 15480, 15481, 15482, 15483,
#        15484, 15485, 15486, 15487, 15488, 15489, 15490, 15491, 15492,
#        15493, 15494, 15495, 15496, 15497, 15498, 15499, 15500, 15501,
#        15502, 15503, 15504, 15505, 15506, 15507, 15508, 15509, 15510,
#        15511, 15512, 15513, 15514, 15515, 15516, 15517, 15518, 15519,
#        15520, 15521, 15522, 15523, 15524, 15525, 15526, 15527, 15528,
#        15529, 15530, 15531, 15532, 15533, 15534, 15535, 15536, 15537,
#        15538, 15539, 15540, 15541, 15542, 15543, 15544, 15545, 15546,
#        15547, 15548, 15549, 15550, 15551, 15552, 15553, 15554, 15555,
#        15556, 15557, 15558, 15559, 15560, 15561, 15562, 15563, 15564,
#        15565, 15566, 15567, 15568, 15569, 15570, 15571, 15572, 15573,
#        15574, 15575, 15576, 15577, 15578, 15579, 15580, 15581, 15582,
#        15583, 15584, 15585, 15586, 15587, 15588, 15589, 15590, 15591,
#        15592, 15593, 15594, 15595, 15596, 15597, 15598, 15599, 15600,
#        15601, 15602, 15603, 15604, 15605, 15606, 15607, 15608, 15609,
#        15610, 15611, 15612, 15613, 15614, 15615, 15616, 15617, 15618,
#        15619, 15620, 15621, 15622, 15623, 15624, 15625, 15626, 15627,
#        15628, 15629, 15630, 15631, 15632, 15633, 15634, 15635, 15636,
#        15637, 15638, 15639, 15640, 15641, 15642, 15643, 15644, 15645,
#        15646, 15647, 15648, 15649, 15650, 15651, 15652, 15653, 15654,
#        15655, 15656, 15657, 15658, 15659, 15660, 15661, 15662, 15663,
#        15664, 15665, 15666, 15667, 15668, 15669, 15670, 15671, 15672,
#        15673], dtype=int64)

# %% [markdown]
# the index in the first place:

# %%
two_countries.index.values[0]
# Out:
# 8047

# %% [markdown]
# how many rows for the two countries?

# %%
len(two_countries)
# Out:
# 433

# %%
two_countries.count()
# Out:
# location                               433
# iso_code                               433
# date                                   433
# total_vaccinations                     376
# people_vaccinated                      431
# people_fully_vaccinated                399
# daily_vaccinations_raw                 371
# daily_vaccinations                     431
# total_vaccinations_per_hundred         376
# people_vaccinated_per_hundred          431
# people_fully_vaccinated_per_hundred    399
# daily_vaccinations_per_million         431
# dtype: int64

# %% [markdown]
# At the end of the file we have some world data.
#
# Use str.contains if you're not sure how this location is called

# %%
vacc_df[vacc_df['location'].str.contains('Worl')]
# Out:
#       location  iso_code        date  total_vaccinations  people_vaccinated  \
# 34612    World  OWID_WRL  2020-12-02        0.000000e+00       0.000000e+00
# 34613    World  OWID_WRL  2020-12-03        0.000000e+00       0.000000e+00
# 34614    World  OWID_WRL  2020-12-04        1.000000e+00       1.000000e+00
# 34615    World  OWID_WRL  2020-12-05        1.000000e+00       1.000000e+00
# 34616    World  OWID_WRL  2020-12-06        1.000000e+00       1.000000e+00
# ...        ...       ...         ...                 ...                ...
# 34840    World  OWID_WRL  2021-07-18        3.662774e+09       2.055135e+09
# 34841    World  OWID_WRL  2021-07-19        3.695078e+09       2.067338e+09
# 34842    World  OWID_WRL  2021-07-20        3.727059e+09       2.079488e+09
# 34843    World  OWID_WRL  2021-07-21        3.760632e+09       2.087375e+09
# 34844    World  OWID_WRL  2021-07-22        3.787027e+09       2.092904e+09
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 34612                      NaN                     NaN                 NaN
# 34613                      NaN                     0.0                 0.0
# 34614                      NaN                     1.0                 0.0
# 34615                      NaN                     0.0                 0.0
# 34616                      NaN                     0.0                 0.0
# ...                        ...                     ...                 ...
# 34840             1.015653e+09              19296764.0          30735269.0
# 34841             1.025288e+09              32304332.0          31101056.0
# 34842             1.033198e+09              31980155.0          30874061.0
# 34843             1.043255e+09              33573399.0          30413169.0
# 34844             1.048364e+09              26394993.0          29076881.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 34612                            0.00                           0.00
# 34613                            0.00                           0.00
# 34614                            0.00                           0.00
# 34615                            0.00                           0.00
# 34616                            0.00                           0.00
# ...                               ...                            ...
# 34840                           46.99                          26.37
# 34841                           47.40                          26.52
# 34842                           47.81                          26.68
# 34843                           48.25                          26.78
# 34844                           48.58                          26.85
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 34612                                  NaN                             NaN
# 34613                                  NaN                             0.0
# 34614                                  NaN                             0.0
# 34615                                  NaN                             0.0
# 34616                                  NaN                             0.0
# ...                                    ...                             ...
# 34840                                13.03                          3943.0
# 34841                                13.15                          3990.0
# 34842                                13.25                          3961.0
# 34843                                13.38                          3902.0
# 34844                                13.45                          3730.0
#
# [233 rows x 12 columns]

# %% [markdown]
# Remove the world data:

# %%
vacc_df_noWorld = vacc_df.loc[vacc_df.location != 'World']
vacc_df_noWorld.tail()
# Out:
#        location iso_code        date  total_vaccinations  people_vaccinated  \
# 35158  Zimbabwe      ZWE  2021-07-17           1771434.0          1132045.0
# 35159  Zimbabwe      ZWE  2021-07-18           1785533.0          1144379.0
# 35160  Zimbabwe      ZWE  2021-07-19           1827638.0          1184435.0
# 35161  Zimbabwe      ZWE  2021-07-20           1897337.0          1247494.0
# 35162  Zimbabwe      ZWE  2021-07-21           1949472.0          1292642.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 35158                 639389.0                 39694.0             41958.0
# 35159                 641154.0                 14099.0             42019.0
# 35160                 643203.0                 42105.0             42253.0
# 35161                 649843.0                 69699.0             45971.0
# 35162                 656830.0                 52135.0             47976.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 35158                           11.92                           7.62
# 35159                           12.01                           7.70
# 35160                           12.30                           7.97
# 35161                           12.77                           8.39
# 35162                           13.12                           8.70
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 35158                                 4.30                          2823.0
# 35159                                 4.31                          2827.0
# 35160                                 4.33                          2843.0
# 35161                                 4.37                          3093.0
# 35162                                 4.42                          3228.0

# %% [markdown]
# Find the country with the maximum vaccinations:

# %%
max_vacc = vacc_df_noWorld['total_vaccinations'].max()
max_vacc
# Out:
# 2383659444.0

# %%
vacc_df_noWorld.loc[vacc_df_noWorld.total_vaccinations == max_vacc]
# Out:
#      location  iso_code        date  total_vaccinations  people_vaccinated  \
# 1950     Asia  OWID_ASI  2021-07-22        2.383659e+09       1.246089e+09
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 1950              461410827.0              19637719.0          19995909.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 1950                           51.37                          26.86
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 1950                                 9.94                          4310.0

# %% [markdown]
# What do you think this function does?

# %%
vacc_df_noWorld.total_vaccinations.mean()
# Out:
# 36918988.861587614

# %% [markdown]
# ----
# #### Your turn:

# %% [markdown]
# Select the number of daily vaccinations in Israel on date 2021-02-06 (hint: use &)

# %%
vacc_df.loc[(vacc_df.location == 'Israel') & (vacc_df.date == '2021-07-20')]
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 15671   Israel      ISR  2021-07-20          11008624.0          5750067.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 15671                5258557.0                 14231.0             10060.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 15671                          127.19                          66.43
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 15671                                60.75                          1162.0

# %% [markdown]
# Find all the countries with more than 3000000 vaccinations

# %%
vacc_df_noWorld.loc[(vacc_df.daily_vaccinations > 300000)]
# Out:
#                   location  iso_code        date  total_vaccinations  \
# 224                 Africa  OWID_AFR  2021-03-27        1.030312e+07
# 225                 Africa  OWID_AFR  2021-03-28        1.056197e+07
# 226                 Africa  OWID_AFR  2021-03-29        1.077488e+07
# 227                 Africa  OWID_AFR  2021-03-30        1.097167e+07
# 267                 Africa  OWID_AFR  2021-05-09        2.119979e+07
# ...                    ...       ...         ...                 ...
# 33674  Upper middle income  OWID_UMC  2021-07-18        1.928636e+09
# 33675  Upper middle income  OWID_UMC  2021-07-19        1.943552e+09
# 33676  Upper middle income  OWID_UMC  2021-07-20        1.961319e+09
# 33677  Upper middle income  OWID_UMC  2021-07-21        1.980014e+09
# 33678  Upper middle income  OWID_UMC  2021-07-22        2.000667e+09
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 224            6962741.0                3606163.0                325837.0
# 225            7218927.0                3608826.0                258849.0
# 226            7305693.0                3743035.0                212915.0
# 227            7387045.0                3870510.0                196785.0
# 267           16063514.0                5518752.0                729471.0
# ...                  ...                      ...                     ...
# 33674        943605954.0              379618270.0              11998743.0
# 33675        945911507.0              381584744.0              14915465.0
# 33676        950175010.0              384027832.0              17767193.0
# 33677        953111895.0              386240484.0              18694961.0
# 33678        955873275.0              388296478.0              20652943.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 224              301268.0                            0.77
# 225              335169.0                            0.79
# 226              348122.0                            0.80
# 227              355345.0                            0.82
# 267              351787.0                            1.58
# ...                   ...                             ...
# 33674          16733054.0                           72.65
# 33675          16626595.0                           73.21
# 33676          16728652.0                           73.88
# 33677          16468485.0                           74.58
# 33678          16617879.0                           75.36
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 224                             0.52                                 0.27
# 225                             0.54                                 0.27
# 226                             0.54                                 0.28
# 227                             0.55                                 0.29
# 267                             1.20                                 0.41
# ...                              ...                                  ...
# 33674                          35.54                                14.30
# 33675                          35.63                                14.37
# 33676                          35.79                                14.47
# 33677                          35.90                                14.55
# 33678                          36.01                                14.63
#
#        daily_vaccinations_per_million
# 224                             225.0
# 225                             250.0
# 226                             260.0
# 227                             265.0
# 267                             262.0
# ...                               ...
# 33674                          6303.0
# 33675                          6263.0
# 33676                          6301.0
# 33677                          6203.0
# 33678                          6260.0
#
# [3614 rows x 12 columns]

# %% [markdown]
# ---
# Summary of the functions in this unit:
#
# >* `.describe()` - View statistical information about the data
# >* `.index.values` - the row indexes of this part of the dataframes
# >* `.str.contains` - selects rows and columns that contain a string
# >* `.max` - maximum value
# >* `.mean` - average value
# >* `.count` - the number of rows that contain a value
# >* `len()` - dataframe length
