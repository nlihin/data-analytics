# %% [markdown]
# # Unit 2 - Reading files and basic selection and description
# ---
#
# 1. [Reading files](#section2)
# 2. [Selecting data](#section3)
# 3. [Describe the data](#section4)

# %% [markdown]
# <a id='section1'></a>

# %% [markdown]
# ## 1. Reading files
# ---
#
# <div>
# <img src="https://github.com/nlihin/data-analytics/blob/main/images/reading.PNG?raw=true" width="400"/>
# </div>
#
#
# We will read the whole file at once using Pandas.
# Sometimes you might want to read the file line by line, and process each line. Thats possible of course. See for example [here.](https://www.geeksforgeeks.org/read-a-file-line-by-line-in-python/)
#
# We will read data on [COVID-19 vaccinations](https://github.com/owid/covid-19-data/tree/master/public/data/vaccinations)
#
# In order to do that, I retrieved the raw data's url
#
# Press on raw either here:
#
# <div>
# <img src="https://github.com/nlihin/data-analytics/blob/main/images/raw.png?raw=true" width="800"/>
# </div>
#
# or here:
#
# <div>
# <img src="https://github.com/nlihin/data-analytics/blob/main/images/unit1_raw2.jpg?raw=true" width="800"/>
# </div>
#
# and retrieve the link:
#
# <div>
# <img src="https://github.com/nlihin/data-analytics/blob/main/images/unit1_raw3.jpg?raw=true" width="800"/>
# </div>

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.csv'
vacc_df = pd.read_csv(url)

# %%
vacc_df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                             0.0
# 1              1367.0                             NaN
# 2              1367.0                             NaN
# 3              1367.0                             NaN
# 4              1367.0                             NaN
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                            0.0                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    total_boosters_per_hundred  daily_vaccinations_per_million  \
# 0                         NaN                             NaN
# 1                         NaN                            33.0
# 2                         NaN                            33.0
# 3                         NaN                            33.0
# 4                         NaN                            33.0
#
#    daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 0                      NaN                                  NaN
# 1                   1367.0                                0.003
# 2                   1367.0                                0.003
# 3                   1367.0                                0.003
# 4                   1367.0                                0.003

# %% [markdown]
# read_csv has about 30 different options. See the
# [documentation](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)
#
# For example, sep='\t' is used for tab delimited files and 'usecol' reads only specific columns.

# %% [markdown]
# ### Basic information

# %%
type(vacc_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# view the shape of the dataframe:

# %%
vacc_df.shape
# Out:
# (186371, 16)

# %% [markdown]
# view basic information:

# %%
vacc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186371 entries, 0 to 186370
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   location                             186371 non-null  object
#  1   iso_code                             186371 non-null  object
#  2   date                                 186371 non-null  object
#  3   total_vaccinations                   80749 non-null   float64
#  4   people_vaccinated                    77288 non-null   float64
#  5   people_fully_vaccinated              74004 non-null   float64
#  6   total_boosters                       48913 non-null   float64
#  7   daily_vaccinations_raw               66703 non-null   float64
#  8   daily_vaccinations                   184939 non-null  float64
#  9   total_vaccinations_per_hundred       80749 non-null   float64
#  10  people_vaccinated_per_hundred        77288 non-null   float64
#  11  people_fully_vaccinated_per_hundred  74004 non-null   float64
#  12  total_boosters_per_hundred           48913 non-null   float64
#  13  daily_vaccinations_per_million       184939 non-null  float64
#  14  daily_people_vaccinated              184649 non-null  float64
#  15  daily_people_vaccinated_per_hundred  184649 non-null  float64
# dtypes: float64(13), object(3)
# memory usage: 22.8+ MB

# %%
vacc_df.columns
# Out:
# Index(['location', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'daily_vaccinations_per_million', 'daily_people_vaccinated',
#        'daily_people_vaccinated_per_hundred'],
#       dtype='object')

# %% [markdown]
# We can view unique values:

# %%
vacc_df['location'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'England', 'Equatorial Guinea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Europe', 'European Union',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana',
#        'Haiti', 'High income', 'Honduras', 'Hong Kong', 'Hungary',
#        'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland',
#        'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey',
#        'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait',
#        'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia',
#        'Libya', 'Liechtenstein', 'Lithuania', 'Low income',
#        'Lower middle income', 'Luxembourg', 'Macao', 'Madagascar',
#        'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Mauritania',
#        'Mauritius', 'Mexico', 'Moldova', 'Monaco', 'Mongolia',
#        'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar',
#        'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia',
#        'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue',
#        'North America', 'North Macedonia', 'Northern Cyprus',
#        'Northern Ireland', 'Norway', 'Oceania', 'Oman', 'Pakistan',
#        'Palestine', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru',
#        'Philippines', 'Pitcairn', 'Poland', 'Portugal', 'Qatar',
#        'Romania', 'Russia', 'Rwanda', 'Saint Helena',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Scotland', 'Senegal',
#        'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tokelau',
#        'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey',
#        'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'Upper middle income', 'Uruguay', 'Uzbekistan',
#        'Vanuatu', 'Venezuela', 'Vietnam', 'Wales', 'Wallis and Futuna',
#        'World', 'Yemen', 'Zambia', 'Zimbabwe'], dtype=object)

# %% [markdown]
# View the first few rows:

# %%
vacc_df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                             0.0
# 1              1367.0                             NaN
# 2              1367.0                             NaN
# 3              1367.0                             NaN
# 4              1367.0                             NaN
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                            0.0                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    total_boosters_per_hundred  daily_vaccinations_per_million  \
# 0                         NaN                             NaN
# 1                         NaN                            33.0
# 2                         NaN                            33.0
# 3                         NaN                            33.0
# 4                         NaN                            33.0
#
#    daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 0                      NaN                                  NaN
# 1                   1367.0                                0.003
# 2                   1367.0                                0.003
# 3                   1367.0                                0.003
# 4                   1367.0                                0.003

# %% [markdown]
# ### <span style="color:blue"> Exercise:</span>
#  >What do you think that the 'tail' command does? Try it out!
# >
# >What happens if we just type vacc_df, without a head or a tail?

# %% [markdown]
# ---
# A summary of the functions so far:
#
# >* `pd.read_csv` - Read data from a CSV file into a Pandas `DataFrame` object
# >* `.info()` - View basic infomation about rows, columns & data types
# >* `.columns` - Get the list of column names
# >* `.shape` - Get the number of rows & columns as a tuple
# >* `.head()`, `.tail()` - View the beginning/end of the file
# >* `.unique()` - view the unique entries in a series (not a dataframe) object

# %% [markdown]
# <a id='section3'></a>

# %% [markdown]
# ---
# ## 2. Selecting data

# %%
vacc_df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                             0.0
# 1              1367.0                             NaN
# 2              1367.0                             NaN
# 3              1367.0                             NaN
# 4              1367.0                             NaN
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                            0.0                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    total_boosters_per_hundred  daily_vaccinations_per_million  \
# 0                         NaN                             NaN
# 1                         NaN                            33.0
# 2                         NaN                            33.0
# 3                         NaN                            33.0
# 4                         NaN                            33.0
#
#    daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 0                      NaN                                  NaN
# 1                   1367.0                                0.003
# 2                   1367.0                                0.003
# 3                   1367.0                                0.003
# 4                   1367.0                                0.003

# %% [markdown]
# #### Selecting a single column:

# %% [markdown]
# **return a single column as a series:**

# %%
vacc_df.location
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 186366       Zimbabwe
# 186367       Zimbabwe
# 186368       Zimbabwe
# 186369       Zimbabwe
# 186370       Zimbabwe
# Name: location, Length: 186371, dtype: object

# %%
vacc_df["location"]
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 186366       Zimbabwe
# 186367       Zimbabwe
# 186368       Zimbabwe
# 186369       Zimbabwe
# 186370       Zimbabwe
# Name: location, Length: 186371, dtype: object

# %% [markdown]
# note: using the `.` notation is possible only for columns whose names do not contain spaces or special characters.

# %% [markdown]
# **return a single column as a dataframe:**

# %%
vacc_df[['location']]
# Out:
#            location
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
# ...             ...
# 186366     Zimbabwe
# 186367     Zimbabwe
# 186368     Zimbabwe
# 186369     Zimbabwe
# 186370     Zimbabwe
#
# [186371 rows x 1 columns]

# %% [markdown]
# #### Selecting a few columns

# %%
vacc_df[['location','date']].head()
# Out:
#       location        date
# 0  Afghanistan  2021-02-22
# 1  Afghanistan  2021-02-23
# 2  Afghanistan  2021-02-24
# 3  Afghanistan  2021-02-25
# 4  Afghanistan  2021-02-26

# %% [markdown]
# #### Select a specific cell:

# %%
vacc_df.location[70000]
# Out:
# 'Guinea-Bissau'

# %% [markdown]
# ---
# ### <span style="color:blue"> Exercise:</span>
# > Now you:
# >
# > (1) Select the `iso_code` column from the `vacc_df` dataframe
# >
# > (2) Select only the `iso_code` at index 3
# >
# > (3) What is the difference between `vacc_df[['location']]` and `vacc_df['location']` and `vacc_df.location` ?  Use `type` to find out

# %% [markdown]
# ---

# %% [markdown]
# ### Seletcting subsets of rows and columns
#
# One way to do that is iloc.
#
# `.iloc` - selects subsets of rows and columns by integer location only

# %%
#vacc_df.iloc[[70000]]  #first row as a series
#vacc_df.iloc[[5,50,50000]]  #first row as a dataframe
#vacc_df.iloc[-1] #last row as a series
vacc_df.iloc[1:5,] #last row as a dataframe
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 1              1367.0                             NaN
# 2              1367.0                             NaN
# 3              1367.0                             NaN
# 4              1367.0                             NaN
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    total_boosters_per_hundred  daily_vaccinations_per_million  \
# 1                         NaN                            33.0
# 2                         NaN                            33.0
# 3                         NaN                            33.0
# 4                         NaN                            33.0
#
#    daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 1                   1367.0                                0.003
# 2                   1367.0                                0.003
# 3                   1367.0                                0.003
# 4                   1367.0                                0.003

# %% [markdown]
# The : operator
#
#  - when used alone it means "everything"
#
# - also used to indicate a ***slice*** of values

# %%
vacc_df.iloc[2:4] # second and third row
#vacc_df.iloc[[-1,2,22]] #a few specific rows

# Columns:
vacc_df.iloc[:,0] # first column of data frame  
vacc_df.iloc[:,[1,2]] # second column of data frame  
#vacc_df.iloc[:,-1] # last column of data frame

#Rows and columns
#vacc_df.iloc[0:5] # first five rows of dataframe
vacc_df.iloc[4:6, 0:2] # first two columns of data frame with all rows
#vacc_df.iloc[[0,3,6,24], [0,5,6]] # 1st, 4th, 7th, 25th row + 1st 6th 7th columns.
# Out:
#       location iso_code
# 4  Afghanistan      AFG
# 5  Afghanistan      AFG

# %% [markdown]
# What if I want to select the 'daily_vaccinations' column, but I don't remember the column number?

# %% [markdown]
# Use `.loc`
#
# `.loc` - selects subsets of rows and columns by label only. Allowed inputs are:
#
# - A single label, e.g. 5 or 'a', (note that 5 is interpreted as a label of the index, and never as an integer position along the index).
#
# - A list or array of labels, e.g. ['a', 'b', 'c'].
#
# - A slice object with labels, e.g. 'a':'f'.

# %%
vacc_df.loc[2:4,['daily_vaccinations','date']]
# Out:
#    daily_vaccinations        date
# 2              1367.0  2021-02-24
# 3              1367.0  2021-02-25
# 4              1367.0  2021-02-26

# %% [markdown]
# I'm missing the location. Let's add it.

# %%
vacc_df.loc[0:3,['location','daily_vaccinations','date']]
# Out:
#       location  daily_vaccinations        date
# 0  Afghanistan                 NaN  2021-02-22
# 1  Afghanistan              1367.0  2021-02-23
# 2  Afghanistan              1367.0  2021-02-24
# 3  Afghanistan              1367.0  2021-02-25

# %% [markdown]
# Semantics are similar to iloc. But note:
#
# - `iloc` excludes the last element.  `df.iloc[0:1000]` will return entries 0...999
# - `loc`, includes the last element.  `df.loc[0:1000]` will return entries 0...1000
#
# you try it! What is the difference between:
#
# > vacc_df.iloc[0:5]
#
# > vacc_df.loc[0:5]

# %%
vacc_df.iloc[0:5]
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                             0.0
# 1              1367.0                             NaN
# 2              1367.0                             NaN
# 3              1367.0                             NaN
# 4              1367.0                             NaN
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                            0.0                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    total_boosters_per_hundred  daily_vaccinations_per_million  \
# 0                         NaN                             NaN
# 1                         NaN                            33.0
# 2                         NaN                            33.0
# 3                         NaN                            33.0
# 4                         NaN                            33.0
#
#    daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 0                      NaN                                  NaN
# 1                   1367.0                                0.003
# 2                   1367.0                                0.003
# 3                   1367.0                                0.003
# 4                   1367.0                                0.003

# %%
vacc_df.loc[0:5]
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
# 5  Afghanistan      AFG  2021-02-27                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
# 5                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                             0.0
# 1              1367.0                             NaN
# 2              1367.0                             NaN
# 3              1367.0                             NaN
# 4              1367.0                             NaN
# 5              1367.0                             NaN
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                            0.0                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
# 5                            NaN                                  NaN
#
#    total_boosters_per_hundred  daily_vaccinations_per_million  \
# 0                         NaN                             NaN
# 1                         NaN                            33.0
# 2                         NaN                            33.0
# 3                         NaN                            33.0
# 4                         NaN                            33.0
# 5                         NaN                            33.0
#
#    daily_people_vaccinated  daily_people_vaccinated_per_hundred
# 0                      NaN                                  NaN
# 1                   1367.0                                0.003
# 2                   1367.0                                0.003
# 3                   1367.0                                0.003
# 4                   1367.0                                0.003
# 5                   1367.0                                0.003

# %% [markdown]
# ---
# ### <span style="color:blue"> Exercise:</span>
# >Now you:
# >
# >what do you do to select:
# >
# >a. first five rows?
# >
# >b. first two columns, all rows?
# >
# >c. 1st and 3rd row and 2nd and 4th column?
# >
# >d(*). All columns but the first
# ---

# %% [markdown]
# ---
# A summary of the functions in this unit:
#
# >* `.iloc` - selects rows and columns by integer location
# >* `.loc` - selects rows and columns by label location

# %% [markdown]
# Note: indexing operators as the ones working on dictionaries, will also work in pandas. But for more advanced operations, better get used to loc and iloc.
#
# ---

# %% [markdown]
# <a id='section4'></a>

# %% [markdown]
# <a id='section4'></a>

# %% [markdown]
# ## 3. Describe the data:

# %% [markdown]
# Describe the data

# %%
vacc_df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        8.074900e+04       7.728800e+04             7.400400e+04
# mean         4.771172e+08       2.113652e+08             1.932275e+08
# std          1.662537e+09       7.267164e+08             6.699294e+08
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          1.742039e+06       9.065720e+05             8.603392e+05
# 50%          1.226868e+07       6.395639e+06             5.835756e+06
# 75%          1.031762e+08       4.526247e+07             4.295032e+07
# max          1.353262e+10       5.630594e+09             5.177748e+09
#
#        total_boosters  daily_vaccinations_raw  daily_vaccinations  \
# count    4.891300e+04            6.670300e+04        1.849390e+05
# mean     1.252947e+08            7.851187e+05        2.984038e+05
# std      3.908137e+08            3.277409e+06        1.972594e+06
# min      1.000000e+00            0.000000e+00        0.000000e+00
# 25%      4.826500e+05            2.475500e+03        3.070000e+02
# 50%      4.877671e+06            2.355000e+04        4.201000e+03
# 75%      3.647089e+07            1.992900e+05        3.369800e+04
# max      2.802250e+09            4.967320e+07        4.369158e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    80749.000000                   77288.000000
# mean                       119.623756                      52.394396
# std                         84.853560                      29.714746
# min                          0.000000                       0.000000
# 25%                         40.150000                      25.850000
# 50%                        122.060000                      61.875000
# 75%                        191.860000                      77.560000
# max                        406.900000                     129.070000
#
#        people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# count                         74004.000000                48913.000000
# mean                             47.440263                   34.747160
# std                              29.350132                   30.299065
# min                               0.000000                    0.000000
# 25%                              19.590000                    4.960000
# 50%                              55.700000                   34.110000
# 75%                              73.422500                   56.750000
# max                             126.890000                  150.470000
#
#        daily_vaccinations_per_million  daily_people_vaccinated  \
# count                   184939.000000             1.846490e+05
# mean                      1940.643569             1.104290e+05
# std                       3177.040531             8.024418e+05
# min                          0.000000             0.000000e+00
# 25%                        126.000000             5.300000e+01
# 50%                        674.000000             9.170000e+02
# 75%                       2561.000000             1.037100e+04
# max                     117113.000000             2.107126e+07
#
#        daily_people_vaccinated_per_hundred
# count                        184649.000000
# mean                              0.078235
# std                               0.179308
# min                               0.000000
# 25%                               0.002000
# 50%                               0.016000
# 75%                               0.078000
# max                              11.711000

# %% [markdown]
# a note on e: e stands for exponent of 10, and it's always followed by another number, which is the value of the exponent
#
# 10e + 1 = 100
#
# 10e + 2 = 1000

# %% [markdown]
# describe categorical data:

# %%
vacc_df[['location']].describe()
# Out:
#        location
# count    186371
# unique      235
# top       World
# freq       1132

# %% [markdown]
# Note that in this dataset, some of the locations are not countries. For example: `High income`,`Africa`, `World`.

# %% [markdown]
# Count how many times each location is mentioned in the dataset

# %%
vacc_df[['location']].value_counts()
# Out:
# location
# World                              1132
# High income                        1131
# Europe                             1131
# European Union                     1129
# Upper middle income                1119
#                                    ...
# Monaco                              357
# Bosnia and Herzegovina              353
# Bonaire Sint Eustatius and Saba     146
# Saint Helena                         92
# Falkland Islands                     67
# Length: 235, dtype: int64

# %% [markdown]
# ---
# ## Summary of the functions in this unit:
#
# >* `.describe()` - View statistical information about the data
# >* `value_counts` - counts how many times a certain value appears in a column
