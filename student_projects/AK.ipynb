# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeClassifier
import sklearn.tree as tree
import sklearn as sk

url = 'https://raw.githubusercontent.com/Avivbiton770/Data-science/main/USA_cars_datasets.csv'
us_car_data = pd.read_csv(url)


from IPython.core.display import Image
Image(url= "https://raw.githubusercontent.com/Avivbiton770/Data-science/main/cars.png", width=650, height=650)
# Out:
# <img src="https://raw.githubusercontent.com/Avivbiton770/Data-science/main/cars.png" width="650" height="650"/>

# %% [markdown]
# ### Edit the file

# %%
us_car_data.head()
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %% [markdown]
# המרת עמודה'קונדישן' המייצגת עבורנו "זמן מדף" של המכונית עד שנמכרה לערכים נומרים  ע"י יצירת עמודה חדשה ואיתור המילים הדומות וכפלתן בערכים שבו מספר ימים יהפכו לשעות . והורדת העמודות הלא רלוונטיות בקובץ.

# %%
us_car_data['num']=us_car_data.condition.str.extract(r'(\d+)').astype(float)
us_car_data['hour']=1
us_car_data.loc[us_car_data.condition.str.contains('day'),'hour']=24
us_car_data[us_car_data.condition.str.contains('day')]['hour']
us_car_data['hour']=us_car_data['hour']*us_car_data.num
us_car_data
# Out:
#       Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0              0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1              1   2899       ford       se  2011  clean vehicle  190552.0
# 2              2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3              3  25000       ford     door  2014  clean vehicle   64146.0
# 4              4  27700  chevrolet     1500  2018  clean vehicle    6654.0
# ...          ...    ...        ...      ...   ...            ...       ...
# 2494        2494   7800     nissan    versa  2019  clean vehicle   23609.0
# 2495        2495   9200     nissan    versa  2018  clean vehicle   34553.0
# 2496        2496   9200     nissan    versa  2018  clean vehicle   31594.0
# 2497        2497   9200     nissan    versa  2018  clean vehicle   32557.0
# 2498        2498   9200     nissan    versa  2018  clean vehicle   31371.0
#
#        color                  vin        lot       state country  \
# 0      black    jtezu11f88k007763  159348797  new jersey     usa
# 1     silver    2fmdk3gc4bbb02217  166951262   tennessee     usa
# 2     silver    3c4pdcgg5jt346413  167655728     georgia     usa
# 3       blue    1ftfw1et4efc23745  167753855    virginia     usa
# 4        red    3gcpcrec2jg473991  167763266     florida     usa
# ...      ...                  ...        ...         ...     ...
# 2494     red    3n1cn7ap9kl880319  167722715  california     usa
# 2495  silver    3n1cn7ap5jl884088  167762225     florida     usa
# 2496  silver    3n1cn7ap9jl884191  167762226     florida     usa
# 2497   black    3n1cn7ap3jl883263  167762227     florida     usa
# 2498  silver    3n1cn7ap4jl884311  167762228     florida     usa
#
#           condition   num   hour
# 0      10 days left  10.0  240.0
# 1       6 days left   6.0  144.0
# 2       2 days left   2.0   48.0
# 3     22 hours left  22.0   22.0
# 4     22 hours left  22.0   22.0
# ...             ...   ...    ...
# 2494    1 days left   1.0   24.0
# 2495  21 hours left  21.0   21.0
# 2496  21 hours left  21.0   21.0
# 2497    2 days left   2.0   48.0
# 2498  21 hours left  21.0   21.0
#
# [2499 rows x 15 columns]

# %%
fulldatacars=us_car_data.drop(['Unnamed: 0','vin','lot'],axis=1)
fulldatacars
# Out:
#       price      brand    model  year   title_status   mileage   color  \
# 0      6300     toyota  cruiser  2008  clean vehicle  274117.0   black
# 1      2899       ford       se  2011  clean vehicle  190552.0  silver
# 2      5350      dodge      mpv  2018  clean vehicle   39590.0  silver
# 3     25000       ford     door  2014  clean vehicle   64146.0    blue
# 4     27700  chevrolet     1500  2018  clean vehicle    6654.0     red
# ...     ...        ...      ...   ...            ...       ...     ...
# 2494   7800     nissan    versa  2019  clean vehicle   23609.0     red
# 2495   9200     nissan    versa  2018  clean vehicle   34553.0  silver
# 2496   9200     nissan    versa  2018  clean vehicle   31594.0  silver
# 2497   9200     nissan    versa  2018  clean vehicle   32557.0   black
# 2498   9200     nissan    versa  2018  clean vehicle   31371.0  silver
#
#            state country      condition   num   hour
# 0     new jersey     usa   10 days left  10.0  240.0
# 1      tennessee     usa    6 days left   6.0  144.0
# 2        georgia     usa    2 days left   2.0   48.0
# 3       virginia     usa  22 hours left  22.0   22.0
# 4        florida     usa  22 hours left  22.0   22.0
# ...          ...     ...            ...   ...    ...
# 2494  california     usa    1 days left   1.0   24.0
# 2495     florida     usa  21 hours left  21.0   21.0
# 2496     florida     usa  21 hours left  21.0   21.0
# 2497     florida     usa    2 days left   2.0   48.0
# 2498     florida     usa  21 hours left  21.0   21.0
#
# [2499 rows x 12 columns]

# %% [markdown]
# אינפורמציה על הקובץ כדי לקבל תמונת מצב אם ישנם ערכים חסרים או בעייתים.

# %%
fulldatacars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         2499 non-null   int64
#  1   brand         2499 non-null   object
#  2   model         2499 non-null   object
#  3   year          2499 non-null   int64
#  4   title_status  2499 non-null   object
#  5   mileage       2499 non-null   float64
#  6   color         2499 non-null   object
#  7   state         2499 non-null   object
#  8   country       2499 non-null   object
#  9   condition     2499 non-null   object
#  10  num           2479 non-null   float64
#  11  hour          2479 non-null   float64
# dtypes: float64(3), int64(2), object(7)
# memory usage: 234.4+ KB

# %% [markdown]
#  . אנו חברה המעניקה טיווח ייעוץ והכוונה בנושאי סחר מכוניות במגרשים בארצות הברית. יזם אמריקאי מניו יורק שמעוניין להכנס לשוק זה שכר את שירותינו  בידי החברה שלנו ישנו קובץ נתונים גדול של כלל מותגי המכוניות במגרשים בארצות הברית עם מאפיינים שונים כמו מחיר,קילומטר'ז,שנת יצור,צבע,זמן מדף וכו . על מנת לתת שירות ליזם זה אנו ננתח את הקובץ וננסה להגיע למסקנות ונייעץ לו בהתאם.
# כדי לקבל תמונה כללית לגבי המחירים הלקוח ביקש לראות את חמשת הרכבים הכי יקרים שנמצאים במגרשים בארה"ב.

# %%
brandmaxprice=fulldatacars.groupby('brand').max()
brandmaxprice.sort_values('price').tail(5)
# Out:
#                price  model  year       title_status   mileage   color  \
# brand
# bmw            61200     x3  2020  salvage insurance  216657.0   white
# chevrolet      63200   volt  2020  salvage insurance  507985.0  yellow
# dodge          67000    van  2020  salvage insurance  239822.0   white
# ford           74000  wagon  2020  salvage insurance  999999.0  yellow
# mercedes-benz  84900   vans  2019      clean vehicle  110907.0   white
#
#                    state country        condition   num   hour
# brand
# bmw            wisconsin     usa      7 days left  22.0  168.0
# chevrolet        wyoming     usa  Listing Expired  34.0  240.0
# dodge          wisconsin     usa  Listing Expired  53.0  312.0
# ford           wisconsin     usa  Listing Expired  48.0  360.0
# mercedes-benz   new york     usa    20 hours left  20.0   48.0

# %% [markdown]
# אחרי שצפה במחירי הרכבים והנתונים עליהם החליט הלקוח על קריטריונים מסויימים שלפיהם יבחר את הרכבים והם : מיקום הרכב : ניו יורק, שנת רכב: מעל 2013 ומחיר שלא יעלה על 50 אלף דולר לרכב

# %%
new_york_cars=fulldatacars[fulldatacars.state.str.contains('new york')]
new_york_cars
by_mileage_car=new_york_cars[new_york_cars['year']>2013]
data_Cars_Customization=by_mileage_car[by_mileage_car['price']<=50000]
data_Cars_Customization
# Out:
#       price          brand     model  year   title_status   mileage  \
# 31    18500       infiniti       q70  2016  clean vehicle   71967.0
# 36    16600  mercedes-benz      vans  2016  clean vehicle  110907.0
# 41    16600  mercedes-benz      vans  2016  clean vehicle   97983.0
# 176    7900           ford      door  2014  clean vehicle   79422.0
# 397    4150           jeep      door  2014  clean vehicle  108895.0
# 407    7770           jeep      door  2014  clean vehicle   72732.0
# 417    5998        hyundai     doors  2014  clean vehicle  122975.0
# 418    3700          honda     doors  2014  clean vehicle  162824.0
# 695   17700      chevrolet   equinox  2019  clean vehicle   25223.0
# 748   24300      chevrolet      1500  2018  clean vehicle   56296.0
# 760   12300      chevrolet  traverse  2017  clean vehicle   83168.0
# 761   14100      chevrolet  traverse  2017  clean vehicle   58606.0
# 882   25000          dodge     doors  2014  clean vehicle   13239.0
# 885   15810          dodge     doors  2014  clean vehicle   44468.0
# 886   20227          dodge     doors  2014  clean vehicle   62230.0
# 887   20999          dodge     doors  2014  clean vehicle   37082.0
# 889   23495          dodge     doors  2014  clean vehicle   11204.0
# 890   25250          dodge     doors  2014  clean vehicle    7608.0
# 1207  21289           ford     doors  2015  clean vehicle   71955.0
# 1604  18900           ford     doors  2015  clean vehicle   44456.0
# 1608  18288           ford     doors  2015  clean vehicle   45218.0
# 2043  216.0
# 2044  216.0
# 2048  216.0
# 2058  216.0
# 2060  216.0
# 2064  216.0
# 2070  216.0
# 2073  216.0

# %% [markdown]
# #####   כעת נבדוק נתונים נוספים כמו סוג הצבע הפופולרי ביותר ,כמה רכבים יש מכל דגם וכל כמה זמן בממוצע עוזב רכב את המגרש (כל כמה זמן רכב נמכר)

# %%
new_york_ford_cars.boxplot(column=['hour'])
# Out:
# <AxesSubplot:>

# %%
fig, axes = plt.subplots(figsize=(22, 10), ncols=1)
ax=sns.countplot( x="color", data=new_york_ford_cars)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
# Out:
# [Text(0, 0, 'white'),
#  Text(1, 0, 'gray'),
#  Text(2, 0, 'charcoal'),
#  Text(3, 0, 'silver'),
#  Text(4, 0, 'shadow black'),
#  Text(5, 0, 'black'),
#  Text(6, 0, 'green'),
#  Text(7, 0, 'red'),
#  Text(8, 0, 'blue'),
#  Text(9, 0, 'ruby red'),
#  Text(10, 0, 'color:'),
#  Text(11, 0, 'ingot silver metallic'),
#  Text(12, 0, 'oxford white'),
#  Text(13, 0, 'orange'),
#  Text(14, 0, 'white platinum tri-coat metallic'),
#  Text(15, 0, 'magnetic metallic')]

# %%
sns.stripplot(x="model", y="price", data=new_york_ford_cars, jitter=0.05)
# Out:
# <AxesSubplot:xlabel='model', ylabel='price'>

# %% [markdown]
# ##### ניתן לשים לב שבדגם הפופולרי ביותר קיים מנעד רחב של מחירים

# %% [markdown]
# #### נבדוק קורולציות בין המשתנים

# %%
spr_data=new_york_ford_cars[['price','year','mileage','hour']].corr(method='spearman').round(2)
sns.heatmap(data=spr_data,cmap='Blues', annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.regplot(x='year', y='price', data=new_york_ford_cars)
# Out:
# <AxesSubplot:xlabel='year', ylabel='price'>

# %% [markdown]
# #### מגרף זה ניתן לראות ששנת 2017 שיחסית שנה מתקדמת יש כמה רכבים שמכירם נמוך יחסית . עלה בדעתנו לבדוק את הרכב האידיאלי ללקוחות עם בעיה כלכלית שרוצים רכב די חדיש של פורד. והוא מתבסס על שנת יצור עדכנית במחיר נמוך .
# ##### במקרים שלקוחות מוגבלים כלכלית ורוצים לרכוש פורד די חדישה ממגרש המכוניות אנו נמליץ ליזם שיקדיש לנישה הזו את הרכבים האלו שיתנו מענה איכותי לבקשות אלה וכך השירות והמענה הכלכלי יעלה רמה אחת מעל בחברה  .
# #####  בנוסף לגרף זה רצינו לבדוק לאותם רכבים מהו הרכב בעל הקילומטר'ז הכי נמוך כדי למקסם את הכדאיות של רכישת הרכב

# %%
desirable_car=new_york_ford_cars[new_york_ford_cars['year']==2017]
desirable_car2=desirable_car[desirable_car['price']>=5000]
desirable_car3=desirable_car2[desirable_car2['price']<=20000]
desirable_car3.sort_values('mileage')
# Out:
#       price brand     model  year   title_status   mileage   color     state  \
# 1781  12100  ford    escape  2017  clean vehicle   32284.0  silver  new york
# 1788  18800  ford  explorer  2017  clean vehicle   76258.0    gray  new york
# 1787  17200  ford     f-150  2017  clean vehicle   91979.0   white  new york
# 1783   9500  ford    escape  2017  clean vehicle  107569.0   white  new york
#
#      country      condition   num  hour
# 1781     usa  18 hours left  18.0  18.0
# 1788     usa  18 hours left  18.0  18.0
# 1787     usa  18 hours left  18.0  18.0
# 1783     usa  18 hours left  18.0  18.0

# %%
ax = sns.stripplot(x="year", y="hour", data=new_york_ford_cars, jitter=0.1)
ax.set(ylim=(0, 300))
# Out:
# [(0.0, 300.0)]

# %% [markdown]
# ####  התפלגות זו מחזקת את מסקנתנו מהגרף הקודם שבשנת 2017 יש את הרכבים הכי אטרקטיבים -מכיוון שמגיע כאן נתון מעניין שבנוסף לטווח המחירים היחסית נמוכים והקילומטר'ז הנמוך, ברכבים האלה זמן המדף היה הכי קצר משמע הם נמכרו הכי מהר

# %%
sns.regplot(x='mileage', y='price', data=new_york_ford_cars);

# %% [markdown]
# #### כמצופה ניתן לראות קשר בין ירידת מחיר הרכב לבין גידול בקילומטר'ז .

# %% [markdown]
# עקב הרצון של החברה שלנו להתייעל מול היזם רצינו לבנות מודל שיינבא ככל הניתן את מחיר הרכב בהתחם לפרמטרים של שנת יצור קילומטר'ז וזמן מדף.

# %%
features1 = ['year','mileage','hour']
x1 = new_york_ford_cars[features1]
y1 = new_york_ford_cars['price']
x1_train, x1_test, y1_train, y1_test = sk.model_selection.train_test_split(x1, y1, test_size=0.3, random_state=42)
model1 = DecisionTreeRegressor(random_state=42)
model1.fit(x1_train,y1_train)

def eval(x1_test,y1_test,model1):
    pred1 = model1.predict(x1_test)
    print("MSE: {:.3f}".format(mean_squared_error(pred1,y1_test,squared=False)))
eval(x1_test,y1_test,model1)
# Out:
# MSE: 7836.882

# %% [markdown]
# בדיקת סטיות התקן (לכמת את רמת הסיכוי לנחש את המטרה לפי המשתנים השונים)

# %%
y1_test.std()
# Out:
# 7095.685402646691

# %% [markdown]
# עקב המודל הלא מדוייק שקיבלנו חשבנו להתייעל ע"פ מודל אחר שהוא - ניבוי שנת הרכב בהתאם לפרמטרים של מחיר,קילומטר'ז וזמן מדף.

# %%
features2 = ['price','mileage','hour']
X2 = new_york_ford_cars[features2]
y2 = new_york_ford_cars['year']
X2_train, X2_test, y2_train, y2_test = sk.model_selection.train_test_split(X2, y2, test_size=0.3, random_state=1)

model2 = DecisionTreeRegressor(random_state=42)
model2.fit(X2_train,y2_train)

def eval(x2_test,y2_test,model2):
    pred2 = model2.predict(x2_test)
    print("MSE: {:.3f}".format(mean_squared_error(pred2,y2_test,squared=False)))
eval(X2_test,y2_test,model2)
# Out:
# MSE: 0.866

# %%
y2_test.std()
# Out:
# 1.3568010505999362

# %% [markdown]
# #### בהתאם לתוצאות שני המודלים אנו רואים בצורה ברורה שהמודל השני ניבא בצורה חד משמעית טובה יותר. לכן נציע ליזם שירות במודל זה על מנת לעזור לו בבחירת הרכבים.
